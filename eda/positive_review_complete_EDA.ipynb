# %%
import re
import numpy as np
import pandas as  pd
from pprint import pprint# Gensim
import gensim
import gensim.corpora as corpora
import gensim.models as genmodels
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import spacy
import pickle
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')


#stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
df = pickle.load(open("../data/merged_hotel_data.pkl", "rb"))
df=df.replace(r'^\s*$', np.nan, regex=True)
print(df.shape)
#df.head()
# Out:
# (76536, 31)

# %%
df.columns
# Out:
# Index(['hotel_name_', 'stars', 'location', 'review_rating', 'description',
#        'main_facilities', 'total_reviews', 'sub_ratings',
#        'sub_ratings_categories', 'sub_ratings_dict', 'hotel_surroundings',
#        'hotel_surroundings_distance', 'surroundings_dict', 'room_type_x',
#        'price_list', 'cheapest_price', 'facilities_groups', 'all_facilities',
#        'link', 'room_price_dict', 'name', 'room_type_y', 'nights_stayed',
#        'month_stayed', 'occupant_type', 'from_country', 'review_score',
#        'date_reviewed', 'short_review', 'positive_review', 'negative_review'],
#       dtype='object')

# %%
default_comments=["Exceptional", "Very Good", "Wonderful", "Good", "Pleasant","Fair", "Disappointing","Bad", "Poor",
                 "Excellent", "Very Poor", "Okay", "Great","Very Good","Ok"]

pattern = '|'.join(default_comments)
df_reviews_sr=df[["positive_review"]].dropna()
df_reviews_sr=df_reviews_sr[~df_reviews_sr.positive_review.str.contains(pattern)]
df_reviews_sr
# Out:
#                                          positive_review
# 0      I like The place and also the staff they're so...
# 1                                               location
# 2                                           The location
# 3                                  Its Near my work area
# 4                                           The location
# ...                                                  ...
# 76531    There are no comments available for this review
# 76532    There are no comments available for this review
# 76533    There are no comments available for this review
# 76534    There are no comments available for this review
# 76535    There are no comments available for this review
#
# [66076 rows x 1 columns]

# %%
# Convert to list 
data = df_reviews_sr.positive_review.values.tolist()  
# # Remove Emails 
# data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]  
# # Remove new line characters 
# data = [re.sub('\s+', ' ', sent) for sent in data]  
# # Remove distracting single quotes 
# data = [re.sub("\'", "", sent) for sent in data]
# #Remove \n
# data = [re.sub("\n", "", sent) for sent in data]
# data = [re.sub("(Image courtesy: )", "", sent) for sent in data]
# #Remove links
# data = [re.sub(r'http\S+', '', sent) for sent in data]
display(len(data))
print(data[8])
# Out:
# 66076
# I booked the location near my residence, but later I was transferred to location with accredited for quarantine. But anyhow, it is a enjoyable stay in your nice hotel! Thank you!

# %% [markdown]
# ### Tokenization

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))            #deacc=True removes punctuations

data_words = list(sent_to_words(data))
print(data_words[:9])
# Out:
# [['like', 'the', 'place', 'and', 'also', 'the', 'staff', 'they', 're', 'so', 'active', 'when', 'im', 'needed', 'something', 'the', 'receptionist', 'also', 'also', 'go', 'back', 'there', 'when', 'have', 'work', 'in', 'east', 'ave', 'thanks', 'so', 'much', 'for', 'they', 're', 'kindness'], ['location'], ['the', 'location'], ['its', 'near', 'my', 'work', 'area'], ['the', 'location'], ['big', 'room'], ['it', 'was', 'located', 'near', 'east', 'ave', 'med', 'center', 'and', 'phc', 'walking', 'distance', 'to', 'these', 'hospitals'], ['reasonable', 'price', 'bug', 'room'], ['booked', 'the', 'location', 'near', 'my', 'residence', 'but', 'later', 'was', 'transferred', 'to', 'location', 'with', 'accredited', 'for', 'quarantine', 'but', 'anyhow', 'it', 'is', 'enjoyable', 'stay', 'in', 'your', 'nice', 'hotel', 'thank', 'you']]

# %% [markdown]
# ### Building the bigram and trigram Models

# %%
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)

# %%
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[8]]])
# Out:
# ['booked', 'the', 'location', 'near', 'my', 'residence', 'but', 'later', 'was', 'transferred', 'to', 'location', 'with', 'accredited', 'for', 'quarantine', 'but', 'anyhow', 'it', 'is', 'enjoyable', 'stay', 'in', 'your', 'nice', 'hotel', 'thank', 'you']

# %% [markdown]
# ### Define function for stopwords, bigrams, trigrams and lemmatization

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN','ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)
data_words_trigrams = make_trigrams(data_words_nostops)

# %%
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en

#nlp = spacy.load('en_core_web_lg')
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])


# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized_bi = lemmatization(data_words_bigrams, allowed_postags=['NOUN'])
data_lemmatized_tri = lemmatization(data_words_trigrams, allowed_postags=['NOUN'])
print(data_lemmatized_bi[-1])
# Out:
# C:\Users\colee\anaconda3\lib\site-packages\spacy\language.py:1895: UserWarning: [W123] Argument disable with value ['parser', 'ner'] is used instead of ['senter'] as specified in the config. Be aware that this might affect other components in your pipeline.
#   warnings.warn(
# ['comment', 'review']

# %%
len(data_lemmatized_bi)
# Out:
# 66076

# %%
id2word_bi = corpora.Dictionary(data_lemmatized_bi)  
id2word_tri = corpora.Dictionary(data_lemmatized_tri)

# %%
texts_bi = data_lemmatized_bi
texts_tri = data_lemmatized_tri

# %%
# Term Document Frequency 
corpus_bi = [id2word_bi.doc2bow(text) for text in texts_bi]  
corpus_tri = [id2word_tri.doc2bow(text) for text in texts_tri]

# %%
# View 
print(corpus_bi[:8])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)], [(6, 1)], [(6, 1)], [(5, 1), (7, 1)], [(6, 1)], [(8, 1)], [(0, 1), (9, 1), (10, 1)], [(8, 1), (11, 1), (12, 1)]]

# %%
[[(id2word_bi[id], freq) for id, freq in cp] for cp in corpus_bi[:1]]
[[(id2word_tri[id], freq) for id, freq in cp] for cp in corpus_tri[:1]]
# Out:
# [[('ave', 1),
#   ('kindness', 1),
#   ('place', 1),
#   ('receptionist', 1),
#   ('thank', 1),
#   ('work', 1)]]

# %%
bow=[[(id2word_tri[id], freq) for id, freq in cp] for cp in corpus_tri]
flat_list = [item for sublist in bow for item in sublist]


no_value_words=["stay","good","hotel","place","nice","great"]

df_bow = pd.DataFrame(flat_list, columns = ['word', 'count'])
df_bow=df_bow[~df_bow.word.str.contains('|'.join(no_value_words))] 
df_bow.groupby("word")["count"].sum().sort_values(ascending=True).tail(10).plot.barh()
# Out:
# <AxesSubplot:ylabel='word'>

# %% [markdown]
# ### Noun Chunks

# %%
data2 = data.copy()

# %%
import spacy
nlp = spacy.load('en_core_web_md')

chunks = []
for i in data2:
    doc = nlp(i)

    for chunk in doc.noun_chunks:
        out = {}
        root = chunk.root
        out[root.pos_] = root
        for tok in chunk:
            if tok != root:
                out[tok.pos_] = tok
        chunks.append(out)

# %%
chunks
# Out:
# [{'PRON': I},
#  {'NOUN': place, 'DET': The},
#  {'NOUN': staff, 'ADV': also, 'DET': the},
#  {'PRON': they},
#  {'PRON': i},
#  {'PRON': Something},
#  {'NOUN': Receptionist, 'DET': the},
#  {'PRON': I},
#  {'PRON': i},
#  {'NOUN': Work},
#  {'PROPN': East},
#  {'NOUN': Thanks},
#  {'PRON': They},
#  {'PROPN': Kindness},
#  {'NOUN': location},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': work, 'PRON': my, 'ADP': Near},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': room, 'ADJ': Big},
#  {'PRON': It},
#  {'PROPN': Med},
#  {'PROPN': PHC},
#  {'NOUN': distance, 'VERB': walking},
#  {'NOUN': hospitals, 'DET': these},
#  {'NOUN': bug, 'ADJ': reasonable},
#  {'PRON': I},
#  {'NOUN': location, 'DET': the},
#  {'NOUN': residence, 'PRON': my},
#  {'PRON': I},
#  {'NOUN': location},
#  {'NOUN': quarantine},
#  {'PRON': it},
#  {'NOUN': stay, 'DET': a, 'ADJ': enjoyable},
#  {'NOUN': hotel, 'PRON': your, 'ADJ': nice},
#  {'PRON': you},
#  {'NOUN': Accessibility},
#  {'NOUN': place, 'DET': the},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': property, 'DET': the},
#  {'PRON': It},
#  {'NOUN': hospital, 'DET': the},
#  {'NOUN': rooms, 'ADJ': big},
#  {'NOUN': rooms, 'ADJ': big},
#  {'NOUN': staff, 'DET': The},
#  {'NOUN': staff, 'DET': The},
#  {'PRON': i},
#  {'NOUN': service},
#  {'NOUN': breakfast, 'DET': No},
#  {'PRON': Everything},
#  {'PRON': I},
#  {'PRON': it},
#  {'PRON': it},
#  {'PRON': it},
#  {'NOUN': Budget, 'ADJ': friendly},
#  {'PRON': I},
#  {'NOUN': company, 'DET': the},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': staff, 'ADJ': Generous},
#  {'NOUN': surrounding, 'ADJ': Quiet},
#  {'PROPN': AC},
#  {'NOUN': staff,
#   'ADV': Very,
#   'VERB': accommodating,
#   'CCONJ': and,
#   'ADJ': friendly},
#  {'NOUN': location, 'DET': a, 'ADJ': prime},
#  {'NOUN': facilities, 'ADJ': nearby},
#  {'NOUN': room, 'DET': The},
#  {'NOUN': air, 'DET': the},
#  {'PRON': everything},
#  {'NOUN': Staff},
#  {'NOUN': school, 'DET': the},
#  {'NOUN': child, 'PRON': my},
#  {'NOUN': room, 'ADJ': clean, 'CCONJ': and},
#  {'NOUN': sheets, 'DET': The, 'VERB': fitted},
#  {'NOUN': bed, 'DET': the},
#  {'PRON': they},
#  {'NOUN': size, 'DET': a, 'ADJ': bigger},
#  {'PRON': it},
#  {'NOUN': room, 'DET': a, 'ADJ': great},
#  {'NOUN': price, 'DET': a, 'ADJ': great},
#  {'PRON': I},
#  {'NOUN': visit, 'PRON': my, 'ADJ': future},
#  {'NOUN': place, 'DET': This},
#  {'NOUN': value, 'DET': a, 'ADJ': great},
#  {'NOUN': money},
#  {'NOUN': location, 'ADJ': convenient},
#  {'NOUN': staff, 'ADJ': helpful},
#  {'PRON': you},
#  {'NOUN': kind, 'DET': the},
#  {'NOUN': minute, 'PRON': our, 'ADJ': last},
#  {'NOUN': regards},
#  {'NOUN': interior, 'DET': the},
#  {'PRON': it},
#  {'NOUN': night, 'DET': a},
#  {'NOUN': friend, 'DET': a},
#  {'NOUN': duty, 'PRON': our, 'ADJ': late},
#  {'NOUN': hospital, 'DET': a, 'ADJ': nearby},
#  {'PRON': it},
#  {'NOUN': budget, 'PRON': our},
#  {'PRON': it},
#  {'PROPN': City, 'DET': the},
#  {'PRON': which},
#  {'PRON': we},
#  {'NOUN': time, 'DET': the, 'ADJ': first},
#  {'NOUN': things, 'SCONJ': how, 'ADJ': much},
#  {'PRON': you},
#  {'NOUN': room, 'PRON': Our},
#  {'NOUN': staff, 'DET': the},
#  {'PRON': i},
#  {'NOUN': stay, 'ADJ': overnight},
#  {'NOUN': staff},
#  {'NOUN': desk, 'DET': the, 'ADJ': front},
#  {'PRON': I},
#  {'PRON': I},
#  {'PRON': He},
#  {'PRON': me},
#  {'NOUN': toiletries, 'DET': some},
#  {'PRON': that},
#  {'PRON': I},
#  {'PRON': me},
#  {'PRON': that},
#  {'NOUN': bonus, 'DET': a, 'ADJ': big},
#  {'PRON': me},
#  {'PRON': nothing},
#  {'NOUN': Location},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'PRON': It},
#  {'NOUN': airport, 'DET': the},
#  {'NOUN': house},
#  {'NOUN': meals, 'ADJ': other},
#  {'NOUN': plenty},
#  {'NOUN': places, 'ADJ': nice},
#  {'NOUN': walking},
#  {'NOUN': cleanliness},
#  {'NOUN': staff, 'ADJ': Friendly},
#  {'NOUN': cause, 'ADJ': late},
#  {'NOUN': flight},
#  {'NOUN': staff},
#  {'NOUN': place, 'DET': this},
#  {'NOUN': layover, 'PRON': my, 'ADJ': long},
#  {'PROPN': Manila},
#  {'PRON': They},
#  {'NOUN': cat, 'DET': a},
#  {'PRON': that},
#  {'PRON': which},
#  {'NOUN': point, 'DET': a, 'ADJ': plus},
#  {'PRON': I},
#  {'NOUN': feeling, 'DET': the},
#  {'NOUN': home},
#  {'NOUN': staff, 'PRON': your, 'VERB': accomodating},
#  {'PRON': I},
#  {'NOUN': interior, 'DET': the},
#  {'NOUN': bathroom, 'DET': the},
#  {'PRON': All},
#  {'PRON': I},
#  {'NOUN': breakfast},
#  {'PRON': I},
#  {'PRON': them},
#  {'NOUN': breakfast},
#  {'PRON': me},
#  {'PRON': it},
#  {'PRON': It},
#  {'NOUN': coffee, 'ADV': specially, 'VERB': brewed},
#  {'PROPN': Carl},
#  {'NOUN': manager, 'DET': the},
#  {'NOUN': hugh, 'DET': a},
#  {'PRON': me},
#  {'NOUN': immigration},
#  {'PRON': me},
#  {'NOUN': care},
#  {'NOUN': visa, 'PRON': my},
#  {'PRON': it},
#  {'PRON': him},
#  {'NOUN': Owners},
#  {'PRON': we},
#  {'NOUN': islands, 'DET': the},
#  {'NOUN': flight, 'PRON': our},
#  {'PRON': they},
#  {'NOUN': suitcases, 'PRON': our, 'ADJ': larger},
#  {'PRON': us},
#  {'NOUN': charge},
#  {'NOUN': beds, 'ADJ': Comfortable},
#  {'NOUN': air},
#  {'NOUN': complaints, 'DET': no},
#  {'NOUN': staff, 'ADJ': friendly},
#  {'NOUN': position, 'ADJ': good},
#  {'NOUN': airport, 'DET': the},
#  {'NOUN': area, 'DET': a, 'ADJ': safe, 'CCONJ': and},
#  {'PRON': we},
#  {'NOUN': family, 'DET': a, 'ADJ': comfortable},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': airport, 'DET': the},
#  {'NOUN': host, 'DET': The},
#  {'PRON': us},
#  {'NOUN': taxi, 'DET': a},
#  {'NOUN': thanks, 'ADJ': Many},
#  {'PRON': everything},
#  {'NOUN': host, 'ADJ': dear},
#  {'PRON': I},
#  {'NOUN': owner, 'DET': the},
#  {'PRON': she},
#  {'PRON': me},
#  {'PRON': she},
#  {'NOUN': kg, 'PRON': my, 'NUM': 20},
#  {'NOUN': floor, 'DET': the, 'PROPN': thirt},
#  {'PRON': she},
#  {'NOUN': room, 'DET': the},
#  {'NOUN': price, 'DET': the},
#  {'NOUN': people, 'ADV': Very, 'ADJ': nice},
#  {'PRON': us},
#  {'NOUN': taxi},
#  {'NOUN': am, 'NUM': 2},
#  {'PROPN': Karl},
#  {'PROPN': amber},
#  {'NOUN': proximity, 'ADJ': close, 'CCONJ': and},
#  {'NOUN': airport, 'DET': the},
#  {'PRON': I},
#  {'NOUN': idea, 'DET': the},
#  {'NOUN': home, 'DET': a, 'ADJ': private},
#  {'NOUN': housing, 'DET': a, 'ADJ': middle, 'PUNCT': -},
#  {'NOUN': area, 'DET': a, 'ADJ': commercial},
#  {'NOUN': security, 'ADJ': heavy},
#  {'NOUN': terms},
#  {'PRON': who},
#  {'NOUN': house, 'DET': The},
#  {'NOUN': rooms, 'ADV': only, 'NUM': three},
#  {'NOUN': touch, 'DET': the, 'ADJ': personal},
#  {'PRON': I},
#  {'NOUN': eatery, 'DET': a, 'ADJ': Chinese, 'PROPN': Thai, 'PUNCT': -},
#  {'NOUN': minutes, 'NUM': five, 'PART': '},
#  {'NOUN': meal, 'DET': a},
#  {'PRON': me},
#  {'NOUN': alcohol, 'DET': no},
#  {'PROPN': Homestay},
#  {'PRON': one},
#  {'NOUN': place, 'DET': a},
#  {'NOUN': lots},
#  {'NOUN': group, 'ADJ': social},
#  {'PRON': I},
#  {'PROPN': Skylab213B},
#  {'NOUN': return, 'PRON': my},
#  {'PROPN': Manila},
#  {'PROPN': January},
#  {'NOUN': Hosts},
#  {'NOUN': accommodation, 'DET': the},
#  {'NOUN': airport, 'DET': the},
#  {'NOUN': Room},
#  {'NOUN': staff},
#  {'NOUN': location, 'ADJ': good},
#  {'NOUN': price, 'ADJ': cheap},
#  {'NOUN': caretaker, 'DET': The},
#  {'PRON': It},
#  {'NOUN': environment, 'DET': a, 'ADJ': quiet},
#  {'NOUN': parking, 'DET': the, 'ADJ': free},
#  {'NOUN': days, 'NUM': 5},
#  {'NOUN': place, 'DET': the},
#  {'PROPN': NAIA, 'DET': the},
#  {'NOUN': owners},
#  {'NOUN': mother},
#  {'NOUN': daughter},
#  {'NOUN': helper, 'DET': the},
#  {'NOUN': place, 'DET': the},
#  {'NOUN': decors},
#  {'PRON': everything},
#  {'PRON': it},
#  {'NOUN': home, 'DET': a, 'PUNCT': "},
#  {'PRON': us},
#  {'NOUN': host, 'DET': The},
#  {'PRON': me},
#  {'NOUN': home, 'DET': a},
#  {'NOUN': home},
#  {'PROPN': Carl},
#  {'PRON': he},
#  {'NOUN': meal, 'ADJ': good},
#  {'PRON': They},
#  {'PRON': me},
#  {'NOUN': area, 'DET': the, 'VERB': receiving},
#  {'NOUN': wifi, 'DET': the},
#  {'NOUN': flight, 'PRON': my},
#  {'NOUN': night},
#  {'NOUN': host, 'PRON': What, 'DET': a, 'ADJ': great},
#  {'NOUN': review, 'DET': This},
#  {'PRON': it},
#  {'NOUN': guidelines, 'PRON': our},
#  {'NOUN': place, 'ADJ': Amazing},
#  {'NOUN': guster, 'DET': an, 'ADJ': amazing},
#  {'PRON': you},
#  {'PRON': we},
#  {'PRON': We},
#  {'NOUN': night, 'NUM': one},
#  {'NOUN': experience, 'DET': a, 'ADJ': great},
#  {'NOUN': room, 'PRON': Our},
#  {'NOUN': bathroom, 'DET': the, 'ADJ': shared},
#  {'NOUN': owners, 'DET': The},
#  {'NOUN': facilities, 'DET': The},
#  {'NOUN': staff, 'ADJ': Friendly},
#  {'NOUN': Hosts},
#  {'PRON': us},
#  {'NOUN': Property},
#  {'NOUN': airport, 'PROPN': v},
#  {'NOUN': Hosts},
#  {'NOUN': grab, 'DET': a},
#  {'NOUN': airport, 'DET': the},
#  {'PRON': us},
#  {'PRON': us},
#  {'NOUN': shop, 'DET': the},
#  {'NOUN': village, 'ADJ': local},
#  {'NOUN': host, 'ADV': most, 'ADJ': friendly},
#  {'PRON': I},
#  {'NOUN': airport, 'DET': the},
#  {'PRON': you},
#  {'NOUN': instructions, 'ADV': very, 'ADJ': clear, 'CCONJ': and},
#  {'NOUN': property, 'DET': the},
#  {'NOUN': arrival},
#  {'NOUN': hours, 'ADJ': several},
#  {'NOUN': flights},
#  {'NOUN': stay, 'PRON': my},
#  {'PRON': I},
#  {'NOUN': Friendliness},
#  {'PROPN': Smiles, 'ADJ': Genuine},
#  {'PROPN': Hospitality},
#  {'PROPN': Natural},
#  {'NOUN': Flexibility},
#  {'PROPN': Considerate},
#  {'PROPN': Generous},
#  {'PROPN': Ukelele},
#  {'PROPN': Piano},
#  {'PROPN': ♥},
#  {'NOUN': ▌},
#  {'NOUN': ▌},
#  {'NOUN': ▌},
#  {'NOUN': ▌},
#  {'PRON': I},
#  {'PRON': them},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'PRON': it},
#  {'PRON': It},
#  {'PRON': nothing},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'PRON': I},
#  {'NOUN': breakfast},
#  {'NOUN': stay, 'PRON': my},
#  {'NOUN': time, 'DET': the},
#  {'NOUN': breakfast, 'DET': the},
#  {'PRON': I},
#  {'PRON': I},
#  {'NOUN': breakfast, 'DET': the},
#  {'NOUN': stay, 'PRON': my},
#  {'NOUN': hotel, 'DET': the},
#  {'NOUN': location, 'DET': the},
#  {'PRON': everything},
#  {'NOUN': Staff},
#  {'PRON': Everything},
#  {'NOUN': location},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': Room},
#  {'NOUN': staff, 'DET': the},
#  {'PRON': They},
#  {'PRON': We},
#  {'NOUN': stay, 'DET': a, 'ADJ': relaxing},
#  {'NOUN': laboratories, 'DET': the, 'ADJ': medical},
#  {'NOUN': budget},
#  {'PRON': I},
#  {'NOUN': staffs, 'DET': the},
#  {'NOUN': staff, 'NUM': One, 'ADJ': particular},
#  {'PRON': that},
#  {'NOUN': location, 'ADJ': good},
#  {'NOUN': room, 'DET': The},
#  {'PRON': they},
#  {'PRON': me},
#  {'NOUN': staff, 'DET': the},
#  {'PRON': you},
#  {'NOUN': hotel, 'ADV': centrally, 'VERB': located, 'ADJ': small},
#  {'PROPN': Taft},
#  {'NOUN': number, 'DET': A},
#  {'NOUN': restaurants},
#  {'NOUN': minutes, 'ADJ': less, 'ADP': than, 'NUM': 5},
#  {'NOUN': walk},
#  {'NOUN': staff, 'ADJ': helpful, 'PUNCT': -},
#  {'NOUN': rooms, 'ADJ': Clean},
#  {'NOUN': space, 'ADJ': sufficient},
#  {'NOUN': location},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': room, 'DET': the},
#  {'NOUN': smell, 'DET': the},
#  {'NOUN': dust, 'ADJ': few},
#  {'PRON': I},
#  {'NOUN': sanitizer},
#  {'NOUN': perfume},
#  {'PRON': I},
#  {'NOUN': bed, 'DET': the},
#  {'NOUN': comforter, 'DET': the},
#  {'NOUN': bedsheets, 'DET': the},
#  {'PRON': which},
#  {'NOUN': eyes, 'DET': the},
#  {'NOUN': hotel, 'DET': A, 'ADJ': basic},
#  {'PRON': everything},
#  {'PRON': we},
#  {'NOUN': staff, 'DET': The},
#  {'NOUN': way, 'PRON': their},
#  {'NOUN': information, 'ADJ': useful},
#  {'NOUN': tours},
#  {'NOUN': taxis},
#  {'PRON': me},
#  {'NOUN': Location},
#  {'NOUN': food},
#  {'NOUN': wifi, 'DET': The},
#  {'NOUN': netflix, 'DET': a, 'ADJ': free},
#  {'NOUN': TV, 'DET': the},
#  {'NOUN': bed, 'DET': The},
#  {'NOUN': side, 'DET': the, 'ADJ': positive},
#  {'NOUN': location, 'DET': the},
#  {'PRON': It},
#  {'NOUN': laboratories, 'DET': the, 'ADJ': medical},
#  {'NOUN': bookings, 'ADJ': multiple},
#  {'NOUN': rate, 'DET': the},
#  {'PRON': It},
#  {'NOUN': check},
#  {'PRON': everything},
#  {'PROPN': hassle},
#  {'PROPN': staff, 'ADV': very, 'ADJ': pleasant},
#  {'NOUN': receptionist},
#  {'NOUN': housekeepers, 'PRON': their},
#  {'PROPN': ko},
#  {'PROPN': dun},
#  {'PROPN': WIFI},
#  {'PRON': I},
#  {'NOUN': meeting, 'DET': an, 'ADJ': online},
#  {'NOUN': night},
#  {'PRON': they},
#  {'PRON': it},
#  {'NOUN': thanks},
#  {'PROPN': balikan},
#  {'PROPN': yung},
#  {'NOUN': connection, 'PROPN': WIFI},
#  {'NOUN': guests, 'ADV': super, 'ADJ': adviseable, 'X': sya, 'PROPN': mga},
#  {'NOUN': students},
#  {'PROPN': ng},
#  {'PROPN': mag},
#  {'NOUN': class, 'PROPN': online},
#  {'PROPN': Moreso},
#  {'NOUN': water, 'ADJ': hot},
#  {'NOUN': sila, 'PROPN': aassist},
#  {'PRON': you},
#  {'PRON': I},
#  {'PRON': they},
#  {'NOUN': money},
#  {'PROPN': WIFI, 'PRON': their},
#  {'PRON': it},
#  {'NOUN': stay, 'PRON': my, 'ADJ': entire},
#  {'PRON': it},
#  {'PRON': I},
#  {'NOUN': hotel, 'DET': this},
#  {'PROPN': Manila},
#  {'PRON': it},
#  {'PRON': you},
#  {'NOUN': value, 'ADV': really, 'ADJ': good},
#  {'NOUN': money, 'DET': the},
#  {'PRON': we},
#  {'PROPN': kahit, 'ADV': importante, 'SPACE':  },
#  {'PRON': I},
#  {'NOUN': emails},
#  {'NOUN': calls, 'DET': some},
#  {'PROPN': napansin},
#  {'PROPN': yung},
#  {'PROPN': ko},
#  {'NOUN': delays, 'DET': no},
#  {'NOUN': connection},
#  {'PROPN': nila},
#  {'NOUN': location, 'PROPN': ng},
#  {'PROPN': center},
#  {'PROPN': sa, 'DET': no, 'NOUN': neto},
#  {'PROPN': OYO},
#  {'PRON': I},
#  {'NOUN': place, 'DET': the},
#  {'PRON': Nothing},
#  {'PROPN': OYO},
#  {'NOUN': time, 'DET': the},
#  {'PRON': that},
#  {'PRON': we},
#  {'NOUN': rooms, 'DET': The},
#  {'NOUN': faces, 'ADJ': new},
#  {'PRON': I},
#  {'NOUN': place, 'DET': the},
#  {'PRON': it},
#  {'PROPN': dito},
#  {'PROPN': ulit},
#  {'PROPN': ng, 'NOUN': thanks},
#  {'PROPN': nag},
#  {'PROPN': sa},
#  {'PROPN': sa},
#  {'PRON': nothing},
#  {'NOUN': none},
#  {'NOUN': Location},
#  {'PROPN': CR},
#  {'PROPN': ang},
#  {'PROPN': naka},
#  {'PROPN': mga},
#  {'PROPN': ka},
#  {'NOUN': Internet},
#  {'NOUN': yung},
#  {'NOUN': room},
#  {'NOUN': location, 'ADJ': Perfect},
#  {'PRON': everything},
#  {'NOUN': room, 'ADJ': comfy, 'CCONJ': and},
#  {'NOUN': Internet},
#  {'NOUN': Location},
#  {'PRON': I},
#  {'NOUN': stay, 'DET': a, 'ADJ': great},
#  {'NOUN': Staff},
#  {'NOUN': value, 'ADV': Indeed},
#  {'NOUN': money},
#  {'NOUN': hotel, 'ADJ': Worst},
#  {'PRON': I},
#  {'PRON': I},
#  {'PRON': everything},
#  {'NOUN': Location},
#  {'NOUN': review, 'DET': This},
#  {'PRON': it},
#  {'NOUN': guidelines, 'PRON': our},
#  {'NOUN': location},
#  {'PRON': Nothing},
#  {'NOUN': location, 'ADJ': Nice},
#  {'NOUN': staff},
#  {'NOUN': staff, 'DET': The},
#  {'NOUN': cats, 'DET': The},
#  {'NOUN': Staff, 'DET': the},
#  {'NOUN': Wifi},
#  {'NOUN': Staff},
#  {'NOUN': room, 'DET': The},
#  {'NOUN': staff, 'DET': The},
#  {'NOUN': room, 'ADV': Very, 'ADJ': nice},
#  {'NOUN': price, 'ADJ': cheap},
#  {'NOUN': staff, 'ADV': Very, 'ADJ': courteous},
#  {'NOUN': hotel, 'ADJ': good},
#  {'NOUN': desk, 'DET': The, 'ADJ': front},
#  {'NOUN': service, 'ADJ': Fantastic},
#  {'NOUN': stay, 'PRON': My},
#  {'NOUN': hotel, 'DET': The},
#  {'NOUN': amenities, 'DET': The},
#  {'NOUN': place, 'ADV': Very, 'ADJ': nice},
#  {'NOUN': travelers, 'ADJ': solo},
#  {'PRON': Nothing},
#  {'PRON': I},
#  {'PRON': they},
#  {'NOUN': standard, 'PRON': their},
#  {'NOUN': budget, 'DET': a},
#  {'NOUN': room, 'DET': The},
#  {'NOUN': size},
#  {'NOUN': smell, 'DET': a, 'ADJ': nice},
#  {'PRON': You},
#  {'NOUN': Air, 'DET': a, 'ADJ': chilling, 'PUNCT': -},
#  {'NOUN': housekeeping, 'PROPN': Daily},
#  {'NOUN': towels, 'ADJ': fresh},
#  {'PRON': I},
#  {'NOUN': stay, 'DET': a, 'ADJ': good},
#  {'NOUN': bed, 'DET': The},
#  {'NOUN': sheets},
#  {'NOUN': location, 'DET': the},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'PRON': It},
#  {'NOUN': hotel, 'PRON': your, 'ADJ': simple, 'SYM': /},
#  {'PRON': nothing},
#  {'NOUN': desk, 'DET': the},
#  {'NOUN': vanity},
#  {'PROPN': AC},
#  {'NOUN': room},
#  {'NOUN': staff, 'DET': the},
#  {'PRON': it},
#  {'PRON': it},
#  {'PRON': me},
#  {'PRON': I},
#  {'NOUN': day, 'PRON': my, 'NUM': ten},
#  {'PRON': I},
#  {'NOUN': errands, 'DET': the, 'PUNCT': “},
#  {'PRON': I},
#  {'PRON': them},
#  {'PRON': they},
#  {'PRON': you},
#  {'NOUN': smile, 'DET': a},
#  {'NOUN': need, 'PRON': your, 'DET': every},
#  {'NOUN': deliveries, 'PRON': your},
#  {'PRON': you},
#  {'NOUN': restocks},
#  {'NOUN': towels},
#  {'NOUN': toiletries},
#  {'PRON': you},
#  {'PRON': it},
#  {'PRON': some, 'CCONJ': and},
#  {'NOUN': people, 'DET': the, 'ADJ': friendliest},
#  {'PRON': I},
#  {'PRON': I},
#  {'NOUN': city, 'DET': the},
#  {'NOUN': trip, 'DET': a, 'ADJ': quick},
#  {'NOUN': staff, 'DET': the},
#  {'NOUN': Propert},
#  {'NOUN': highway, 'DET': the},
#  {'NOUN': stores},
#  {'PRON': They},
#  {'NOUN': shower, 'ADJ': hot},
#  {'NOUN': room},
#  {'NOUN': Staff},
#  {'NOUN': staffs},
#  {'NOUN': room, 'ADJ': Spacious},
#  {'NOUN': cr},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': Accessibility},
#  {'NOUN': checkin, 'ADJ': Late},
#  {'NOUN': staff, 'ADJ': helpful, 'CCONJ': and},
#  {'NOUN': staff, 'DET': The},
#  {'NOUN': utility, 'DET': the},
#  {'PRON': it},
#  {'NOUN': place, 'PRON': my},
#  {'NOUN': price},
#  {'NOUN': crews, 'DET': the},
#  {'PRON': I},
#  {'NOUN': price, 'DET': the, 'ADJ': cheap},
#  {'PRON': It},
#  {'NOUN': quarantine, 'DET': a},
#  {'NOUN': location, 'DET': The},
#  {'PRON': it},
#  {'NOUN': mainroad, 'DET': the},
#  {'NOUN': restaurant, 'DET': a},
#  {'NOUN': building, 'DET': the, 'ADJ': same},
#  {'PRON': it},
#  {'NOUN': Staff},
#  {'NOUN': water, 'DET': the},
#  {'NOUN': comfort, 'DET': the},
#  {'NOUN': booking, 'DET': The},
#  {'PRON': we},
#  {'NOUN': price, 'DET': the},
#  {'NOUN': aircon},
#  {'PRON': i},
#  {'NOUN': staff, 'DET': The, 'ADJ': friendly},
#  {'PRON': I},
#  {'NOUN': location, 'DET': the},
#  {'PRON': I},
#  {'PROPN': erea, 'DET': the},
#  {'PRON': I},
#  {'NOUN': review, 'DET': This},
#  {'PRON': it},
#  {'NOUN': guidelines, 'PRON': our},
#  {'PRON': I},
#  {'NOUN': staff, 'DET': the},
#  {'NOUN': cleaner, 'DET': The},
#  {'PROPN': Guards, 'DET': The},
#  {'NOUN': receptionist, 'DET': the},
#  {'NOUN': location, 'DET': The},
#  {'NOUN': transportation, 'ADJ': public},
#  {'NOUN': convenience, 'ADJ': several},
#  {'NOUN': area, 'DET': the},
#  {'NOUN': staff, 'DET': The},
#  {'NOUN': troble, 'DET': Any},
#  {'NOUN': room, 'DET': the},
#  {'NOUN': Aircon},
#  {'NOUN': Location},
#  {'NOUN': Staff},
#  {'NOUN': guest, 'PRON': their},
#  {'NOUN': staff, 'DET': The},
#  {'NOUN': room, 'DET': The},
#  {'NOUN': Cleanliness},
#  {'NOUN': sheets, 'DET': the},
#  {'PRON': it},
#  {'NOUN': hometown, 'PRON': my},
#  {'NOUN': parents, 'PRON': my},
#  {'NOUN': toiletries, 'DET': No},
#  {'NOUN': attendants, 'DET': The},
#  {'NOUN': desk, 'DET': the, 'ADJ': front},
#  {'PRON': we},
#  {'NOUN': hotel, 'PROPN': ng},
#  {'NOUN': quarantine},
#  {'NOUN': assistance, 'ADJ': good},
#  {'NOUN': staff},
#  {'NOUN': problem, 'DET': any},
#  {'NOUN': room},
#  {'NOUN': staff, 'DET': All},
#  {'PROPN': Christine},
#  {'NOUN': desk, 'DET': the, 'ADJ': front},
#  {'PRON': She},
#  {'NOUN': A, 'PROPN': N, 'PUNCT': /},
#  {'NOUN': Value},
#  {'NOUN': money},
#  {'NOUN': Rates},
#  {'NOUN': place},
#  {'NOUN': Price},
#  {'NOUN': goods, 'PRON': all},
#  {'PRON': everything},
#  {'NOUN': staff, 'DET': The, 'ADJ': friendly},
#  {'NOUN': none},
#  {'NOUN': Staff},
#  {'NOUN': security, 'DET': the},
#  {'PROPN': Tv},
#  {'NOUN': wifi},
#  {'NOUN': aircon},
#  {'NOUN': Location},
#  {'PRON': I},
#  {'NOUN': accom, 'PRON': my},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  {'NOUN': review, 'DET': this},
#  {'NOUN': comments, 'DET': no},
#  ...]

# %%
df_chunk = pd.DataFrame.from_dict(chunks)

# %%
df_chunk['NOUN'] = df_chunk['NOUN'].astype(str)
df_chunk['ADJ'] = df_chunk['ADJ'].astype(str)

# %%
import nltk

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return(lemmatizer.lemmatize(text))

df_chunk['NOUN_lemma'] = df_chunk.NOUN.apply(lemmatize_text)
df_chunk['ADJ_lemma'] = df_chunk.ADJ.apply(lemmatize_text)

# %%
def lower_text(text):
    return(text.lower())

df_chunk['NOUN_lemma'] = df_chunk.NOUN.apply(lower_text)
df_chunk['ADJ_lemma'] = df_chunk.ADJ.apply(lower_text)

# %%
df_chunk
# Out:
#         PRON      NOUN   DET   ADV PROPN  ADP  ADJ VERB CCONJ SCONJ  NUM  \
# 0          I       nan   NaN   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 1        NaN     place   The   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 2        NaN     staff   the  also   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 3       they       nan   NaN   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 4          i       nan   NaN   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# ...      ...       ...   ...   ...   ...  ...  ...  ...   ...   ...  ...
# 194736   NaN    review  this   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 194737   NaN  comments    no   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 194738   NaN    review  this   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 194739   NaN  comments    no   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
# 194740   NaN    review  this   NaN   NaN  NaN  nan  NaN   NaN   NaN  NaN
#
#        PUNCT PART    X SPACE  SYM INTJ  AUX NOUN_lemma ADJ_lemma
# 0        NaN  NaN  NaN   NaN  NaN  NaN  NaN        nan       nan
# 1        NaN  NaN  NaN   NaN  NaN  NaN  NaN      place       nan
# 2        NaN  NaN  NaN   NaN  NaN  NaN  NaN      staff       nan
# 3        NaN  NaN  NaN   NaN  NaN  NaN  NaN        nan       nan
# 4        NaN  NaN  NaN   NaN  NaN  NaN  NaN        nan       nan
# ...      ...  ...  ...   ...  ...  ...  ...        ...       ...
# 194736   NaN  NaN  NaN   NaN  NaN  NaN  NaN     review       nan
# 194737   NaN  NaN  NaN   NaN  NaN  NaN  NaN   comments       nan
# 194738   NaN  NaN  NaN   NaN  NaN  NaN  NaN     review       nan
# 194739   NaN  NaN  NaN   NaN  NaN  NaN  NaN   comments       nan
# 194740   NaN  NaN  NaN   NaN  NaN  NaN  NaN     review       nan
#
# [194741 rows x 20 columns]

# %% [markdown]
# # TOP ADJECTIVES DESCRIBING TOP NOUNS

# %% [markdown]
# STAFF

# %%
staff =  df_chunk[(df_chunk['NOUN_lemma'] == 'staff') & (df_chunk['ADJ_lemma'] != 'nan')]
staff = staff[['NOUN_lemma','ADJ_lemma']]


staff_adj = pd.DataFrame({'trans_count': staff['ADJ_lemma'].value_counts().sort_values().tail(10)})

colors_h = ['lightgray'] * 10
colors_h[7:10] = ['#ff0257'] * 3

fig, ax = plt.subplots(figsize=(10, 5))
hbar = ax.barh(staff_adj.index, staff_adj.trans_count, color=colors_h)
for spine in ['right', 'top']:
    ax.spines[spine].set_visible(False)
    
ax.set_title('Top Adjectives Describing Staff')
ax.bar_label(hbar)
plt.show()

# %% [markdown]
# ROOM

# %%
room =  df_chunk[(df_chunk['NOUN_lemma'] == 'room') & (df_chunk['ADJ_lemma'] != "nan")]
room = room[['NOUN_lemma','ADJ_lemma']]


room_adj = pd.DataFrame({'trans_count': room['ADJ_lemma'].value_counts().sort_values().tail(10)})

colors_h = ['lightgray'] * 10
colors_h[7:10] = ['#ff0257'] * 3

fig, ax = plt.subplots(figsize=(10, 5))
hbar = ax.barh(room_adj.index, room_adj.trans_count, color=colors_h)
for spine in ['right', 'top']:
    ax.spines[spine].set_visible(False)
    
ax.set_title('Top Adjectives Describing Room')
ax.bar_label(hbar)
plt.show()

# %% [markdown]
# LOCATION

# %%
loct =  df_chunk[(df_chunk['NOUN_lemma'] == 'location') & (df_chunk['ADJ_lemma'] != "nan")]
loct = loct[['NOUN_lemma','ADJ_lemma']]


loct_adj = pd.DataFrame({'trans_count': loct['ADJ_lemma'].value_counts().sort_values().tail(10)})

colors_h = ['lightgray'] * 10
colors_h[7:10] = ['#ff0257'] * 3

fig, ax = plt.subplots(figsize=(10, 5))
hbar = ax.barh(loct_adj.index, loct_adj.trans_count, color=colors_h)
for spine in ['right', 'top']:
    ax.spines[spine].set_visible(False)
    
ax.set_title('Top Adjectives Describing Location')
ax.bar_label(hbar)
plt.show()

# %% [markdown]
# SERVICE

# %%
mon =  df_chunk[(df_chunk['NOUN_lemma'] == 'service') & (df_chunk['ADJ_lemma'] != "nan")]
mon = mon[['NOUN_lemma','ADJ_lemma']]


mon_adj = pd.DataFrame({'trans_count': mon['ADJ_lemma'].value_counts().sort_values().tail(10)})

colors_h = ['lightgray'] * 10
colors_h[7:10] = ['#ff0257'] * 3

fig, ax = plt.subplots(figsize=(10, 5))
hbar = ax.barh(mon_adj.index, mon_adj.trans_count, color=colors_h)
for spine in ['right', 'top']:
    ax.spines[spine].set_visible(False)
    
ax.set_title('Top Adjectives Describing Location')
ax.bar_label(hbar)
plt.show()

# %% [markdown]
# PRICE

# %%
apt =  df_chunk[(df_chunk['NOUN_lemma'] == 'price') & (df_chunk['ADJ_lemma'] != "nan")]
apt = apt[['NOUN_lemma','ADJ_lemma']]


apt_adj = pd.DataFrame({'trans_count': apt['ADJ_lemma'].value_counts().sort_values().tail(10)})

colors_h = ['lightgray'] * 10
colors_h[7:10] = ['#ff0257'] * 3

fig, ax = plt.subplots(figsize=(10, 5))
hbar = ax.barh(apt_adj.index, apt_adj.trans_count, color=colors_h)
for spine in ['right', 'top']:
    ax.spines[spine].set_visible(False)
    
ax.set_title('Top Adjectives Describing Airport')
ax.bar_label(hbar)
plt.show()
