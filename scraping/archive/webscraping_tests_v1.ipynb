# %% [markdown]
# # Get All Urls

# %% [markdown]
# ## Selenium- All URLS

# %%
from lxml import etree
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from time import sleep
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import numpy as np
import requests


options = Options()
options.add_argument("--headless")
#options.add_argument("--start-maximized")
#options.add_argument("--disable-notifications")
options.add_argument("--incognito")

# %%
from tqdm import tqdm

df_conso = pd.DataFrame()
start=0
end=50
for count, i in tqdm(enumerate(range(start,end*25+1,25))):
    
    
    
    try:
        driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        url="https://www.booking.com/searchresults.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuALP2NGbBsACAdICJGRiYTg5ODViLTY0OWYtNDJmMC05MmQ2LTQzYTNhOTM0OGMzNtgCBeACAQ&sid=62995f74fed87079ecbbad21978f8cb9&aid=304142&ss=Manila&ssne=Manila&ssne_untouched=Manila&efdco=1&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2437894&dest_type=city&checkin=2022-11-25&checkout=2022-11-26&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset="
        driver.get(url+str(i))


        total_height = int(driver.execute_script("return document.body.scrollHeight"))

        for i in range(1, total_height, 5):
            driver.execute_script("window.scrollTo(0, {});".format(i))

        page_source=driver.page_source


        print("Done Exporting Data")
        driver.close()
        driver.quit()
        print("Closed Driver")

        #-----------------------------------------
        soup=bs4.BeautifulSoup(page_source,'lxml')
        dom = etree.HTML(str(soup))
        
        #-----------------------------------------

        links=[i.get("href") for i in dom.xpath("//h3//a")]
        hotel_name=[i.text for i in dom.xpath("//h3//a//div" ) if i.text !='Opens in new window']
        location=[i.text for i in dom.xpath("//div//a//span[@data-testid]") if i.text!=None]
        # description=[i.text for i in dom.xpath("//div[@class='d8eab2cf7f']") if i.text!=None]
        # data=dom.xpath("//div[@data-testid='rating-circles']")
        # star_list=[]
        # for _data in data:
        #     stars=0
        #     for x in _data.findall("span"):
        #         stars=stars+1
        #     star_list.append(stars) 
        # total_reviews=[i.text for i in dom.xpath("//div[@class='d8eab2cf7f c90c0a70d3 db63693c62']")]
        distance=[i.text for i in dom.xpath("//span[@data-testid='distance']")]


        df = pd.DataFrame({'links': links,
                          "hotel_name":hotel_name,
                           "location":location,
                           #"description":description,
                           #"star_list":star_list,
                           #"total_reviews":total_reviews,
                           "distance":distance
                          })
        df["count"]=count
        df_conso=pd.concat([df_conso,df])


    except Exception as e: 
        print(str(e))
        print(count+start)
        driver.close
        driver.quit()
        sleep(3)
        #continue
        break
# Out:
# 0it [00:00, ?it/s]
# Done Exporting Data
# Closed Driver
# 1it [00:34, 34.49s/it]
# Done Exporting Data
# Closed Driver
# 2it [01:10, 35.44s/it]
# Done Exporting Data
# Closed Driver
# 3it [01:45, 35.12s/it]
# Done Exporting Data
# Closed Driver
# 4it [02:20, 34.98s/it]
# Done Exporting Data
# Closed Driver
# 5it [02:55, 35.00s/it]
# Done Exporting Data
# Closed Driver
# 6it [03:30, 35.05s/it]
# Done Exporting Data
# Closed Driver
# 7it [04:04, 34.73s/it]
# Done Exporting Data
# Closed Driver
# 8it [04:41, 35.54s/it]
# Done Exporting Data
# Closed Driver
# 9it [05:16, 35.42s/it]
# Done Exporting Data
# Closed Driver
# 10it [05:51, 35.21s/it]
# Done Exporting Data
# Closed Driver
# 11it [06:26, 35.10s/it]
# Done Exporting Data
# Closed Driver
# 12it [07:01, 35.17s/it]
# Done Exporting Data
# Closed Driver
# 13it [07:35, 34.79s/it]
# Done Exporting Data
# Closed Driver
# 14it [08:13, 35.59s/it]
# Done Exporting Data
# Closed Driver
# 15it [08:49, 35.73s/it]
# Done Exporting Data
# ...

# %%
df_conso.to_csv("data/all_manila_hotels.csv")

# %% [markdown]
# # URL's per page

# %%
df=pd.read_csv("data/all_manila_hotels.csv")
links=df.links

sample=links[0]
sample
# Out:
# 'https://www.booking.com/hotel/ph/diamond-philippines.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuALP2NGbBsACAdICJGRiYTg5ODViLTY0OWYtNDJmMC05MmQ2LTQzYTNhOTM0OGMzNtgCBeACAQ&sid=62995f74fed87079ecbbad21978f8cb9&aid=304142&ucfs=1&arphpl=1&checkin=2022-11-25&checkout=2022-11-26&dest_id=-2437894&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&srpvid=e9da55d35eaa04a2&srepoch=1668773545&all_sr_blocks=29318601_0_2_1_0&highlighted_blocks=29318601_0_2_1_0&matching_block_id=29318601_0_2_1_0&sr_pri_blocks=29318601_0_2_1_0__15305&tpi_r=1&from=searchresults#hotelTmpl'

# %%
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
url=sample
driver.get(url)


total_height = int(driver.execute_script("return document.body.scrollHeight"))

for i in range(1, total_height, 5):
    driver.execute_script("window.scrollTo(0, {});".format(i))

page_source=driver.page_source


print("Done Exporting Data")
driver.close()
driver.quit()
print("Closed Driver")
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.46M/6.46M [00:01<00:00, 4.86MB/s]
# Done Exporting Data
# Closed Driver

# %%
#Requests
# response = requests.request("GET",sample)
# soup = bs4.BeautifulSoup(response.text, 'lxml')

#Selenium
soup=bs4.BeautifulSoup(page_source,'lxml')


dom = etree.HTML(str(soup))

# %%
#Requests
location=[i.text.replace("\n","") for i in dom.xpath("//span[contains(@class, 'address')]")]
review_rating=[i.text.replace("\n","") for i in dom.xpath("//div[contains(@aria-label, 'Scored')]")][0]
location_score=[i.text.replace("\n","") for i in dom.xpath("//span[@class='review-score-badge']")]
descriptions=[i.findall('p') for i in dom.xpath("//div[@id='property_description_content']")]
description=" ".join([i.text for i in descriptions[0]])

facilities=[]
facilities_=[i for i in dom.xpath("//div[@class='hp_desc_important_facilities clearfix hp_desc_important_facilities--bui']")]

for i in facilities_:
    #print(i.findall("div"))
    for ii in i.findall("div"):
        facilities.append(ii.get("data-name-en"))
        
total_reviews=[i.text for i in dom.xpath("//div[@class='d8eab2cf7f c90c0a70d3 db63693c62']")][0].split(" ")[0]
sub_ratings=[i.text for i in dom.xpath("//div[@class='ee746850b6 b8eef6afe1']")][:7]
sub_ratings_categories=[i.text for i in dom.xpath("//span[@class='d6d4671780']")][:7]

# %%
#Selenium

#Kulang- hotel surroundings, facilities Grouped

hotel_surroundings=[i.text for i in dom.xpath("//div[@class='b1e6dd8416 aacd9d0b0a']|//span[@class='b6f930dcc9']") if i.text is not None]
hotel_surroundings_distance=[i.text for i in dom.xpath("//div[@class='db29ecfbe2 c90c0a70d3']") if i.text is not None]
hotel_dict = {hotel_surroundings[i]: hotel_surroundings_distance[i] for i in range(len(hotel_surroundings))}

all_facilities=[i.text.replace('\n',"") for i in dom.xpath("//div[@class='bui-list__description']") if i.text!='\n']
facilities_grouped=[i.text for i in dom.xpath("//div[@class='bui-title__text hotel-facilities-group__title-text']")]


price_list=[float(i.text.replace("\n","").strip().replace(u'₱\xa0', '').replace(",",""))
 for i in dom.xpath("//span[@class='prco-valign-middle-helper']")]

cheapest_price=min(price_list)

facilities_groups=[i.replace("\n","") for i in dom.xpath("//div[@class='bui-title__text hotel-facilities-group__title-text']//text()") if i!='\n']
hfg=dom.xpath("//div[@class='bui-spacer--large']")
all_facilities=[]
for i in hfg:
    data=i.findall("div//div//div")
    facilities_per_group=[i.text.replace("\n","") for i in data if (i.text!="\n") & (i.text!=None)]
    if facilities_per_group !=[]:
        all_facilities.append(facilities_per_group)
    #print("")

# %%
len(facilities_list), len(facilities_groups)
# Out:
# (19, 20)

# %% [markdown]
# ## Reviews

# %%
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))
url=sample
driver.get(url)


total_height = int(driver.execute_script("return document.body.scrollHeight"))

review_button= driver.find_element(By.XPATH,"//a[@data-target= 'hp-reviews-sliding']")
sleep(5)
review_button.click()

# for i in range(1, total_height, 5):
#     driver.execute_script("window.scrollTo(0, {});".format(i))

page_source_reviews=driver.page_source
sleep(5)

print("Done Exporting Data")
driver.close()
driver.quit()
print("Closed Driver")
# Out:
# Done Exporting Data
# Closed Driver

# %%
page_source_reviews
# Out:
# '<html lang="en-gb" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#" xmlns:og="http://opengraphprotocol.org/schema/" class=" b_chrome b_chrome_107 supports_inline-block supports_flexbox_unprefixed supports_fontface  hasJS" dir="ltr"><head><script async="" src="https://s.pinimg.com/ct/lib/main.9a94ee76.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-FPD6YLJCJ7&amp;l=dataLayer&amp;cx=c" nonce=""></script><script type="text/javascript" async="" src="https://bat.bing.com/bat.js" nonce=""></script><script type="text/javascript" async="" src="https://s.pinimg.com/ct/core.js" nonce=""></script><script type="text/javascript" async="" src="https://sc-static.net/scevent.min.js" nonce=""></script><script type="text/javascript" async="" src="https://www.gstatic.com/recaptcha/releases/Km9gKuG06He-isPsP6saG8cn/recaptcha__en.js" crossorigin="anonymous" integrity="sha384-tL/88+JE9Mv/pJzkZt5DB
# ...

# %%
soup_=bs4.BeautifulSoup(page_source_reviews,'lxml')
dom_ = etree.HTML(str(soup_))

# %%
dom_.xpath("//span[@class='c-review__body']")
# Out:
# []

# %% [markdown]
# # Testing- Autoscraper

# %%
from autoscraper import AutoScraper

url=sample
wanted_list=["Pedro Gil Park"]

scraper=AutoScraper()
result=scraper.build(url,wanted_list)
