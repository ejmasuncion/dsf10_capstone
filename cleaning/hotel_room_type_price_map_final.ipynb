# %%
import pandas as pd
import pickle
import seaborn as snsa
from matplotlib import pyplot as plt

# %%
## load scraped data
data = pickle.load(open("../data/hotel_info_final2.pkl", "rb"))
data = data.rename(columns={'url': 'link'})
print(data.shape)
data.head()
# Out:
# (307, 20)
#                                 hotel_name_  stars  \
# 0  RedDoorz near East Avenue Medical Center      2
# 1                         Skylab Guesthouse      2
# 2             The Excelsior Hotel Las Piñas      4
# 3                             Rothman Hotel      3
# 4                OYO 772 Remedios Apartment      3
#
#                                             location review_rating  \
# 0  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1  213B, Aldrin Street, Moonwalk Village 1, Parañ...           8.0
# 2  1345 Alabang–Zapote Road, Las Pinas, 1750 Mani...           7.3
# 3  1633 M. Adriatico St., Malate, 1004 Manila, Ph...           7.8
# 4  909, Remedios St, Manila Malate Manila, 1004 M...           6.8
#
#                                          description  \
# 0  RedDoorz near East Avenue Medical Center featu...
# 1  You're eligible for a Genius discount at Skyla...
# 2  Located in Manila, 12.2 km from Mall of Asia A...
# 3  Rothman Hotel is located in the district of Ma...
# 4  You're eligible for a Genius discount at OYO 7...
#
#                                      main_facilities total_reviews  \
# 0  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1  [Non Smoking Rooms, Spa & Wellness Centre, Fre...            79
# 2  [Swimming pool, Airport Shuttle, Non Smoking R...             6
# 3  [Non Smoking Rooms, Room-service, Free Parking...            45
# 4  [Non Smoking Rooms, Free WiFi Internet Access ...           113
#
#                            sub_ratings  \
# 0  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1  [8.8, 7.8, 8.3, 8.4, 8.4, 8.1, 7.5]
# 2  [7.9, 8.3, 7.9, 8.8, 7.9, 7.9, 7.9]
# 3  [8.3, 7.6, 8.0, 7.8, 7.8, 8.7, 8.8]
# 4  [7.5, 6.5, 6.9, 6.9, 7.0, 7.7, 8.8]
#
#                               sub_ratings_categories  \
# 0  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                     sub_ratings_dict  \
# 0  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...
# 1  {'Staff': '8.8', 'Facilities': '7.8', 'Cleanli...
# 2  {'Staff': '7.9', 'Facilities': '8.3', 'Cleanli...
# 3  {'Staff': '8.3', 'Facilities': '7.6', 'Cleanli...
# 4  {'Staff': '7.5', 'Facilities': '6.5', 'Cleanli...
#
#                                   hotel_surroundings  \
# 0  [Quezon City Hall Park and Lagoon, Children's ...
# 1  [Barcelona Park, Guadalajara Park, Continental...
# 2  [Philamlife Village Park, Jasmin Circle open-c...
# 3  [Pedro Gil Park, Manila Baywalk, Remedios Circ...
# 4  [Remedios Circle, MMDA Children's Road Safety ...
#
#                          hotel_surroundings_distance  \
# 0  [900 m, 900 m, 1.1 km, 1.3 km, 1.6 km, 1.6 km,...
# 1  [950 m, 1.3 km, 1.5 km, 1.6 km, 1.7 km, 1.7 km...
# 2  [550 m, 1,000 m, 1 km, 1 km, 1.2 km, 1.4 km, 1...
# 3  [250 m, 450 m, 450 m, 500 m, 750 m, 950 m, 1,0...
# 4  [600 m, 850 m, 950 m, 950 m, 950 m, 1,000 m, 1...
#
#                                    surroundings_dict  \
# 0  {'Quezon City Hall Park and Lagoon': '900 m', ...
# 1  {'Barcelona Park': '950 m', 'Guadalajara Park'...
# 2  {'Philamlife Village Park': '550 m', 'Jasmin C...
# 3  {'Pedro Gil Park': '250 m', 'Manila Baywalk': ...
# 4  {'Remedios Circle': '600 m', 'MMDA Children's ...
#
#                                            room_type  \
# 0  [Deluxe Room, Economy Double Room, Economy Dou...
# 1  [Double Room, Queen Room, Double Room with Sha...
# 2  [Deluxe Room, Deluxe Room, Executive Room, Exe...
# 3  [Renovated King Room, Deluxe Double Room, Delu...
# 4  [Deluxe Double Room, Deluxe Double Room, Stand...
#
#                                           price_list  cheapest_price  \
# 0  [977.0, 1413.0, 1944.0, 1954.0, 2150.0, 1590.0...           977.0
# 1                           [1709.0, 1709.0, 1709.0]          1709.0
# 2  [3010.0, 3571.0, 3724.0, 4357.0, 4499.0, 5077....          3010.0
# 3           [2160.0, 2545.0, 3223.0, 2545.0, 3223.0]          2160.0
# 4                   [1125.0, 1463.0, 1125.0, 1463.0]          1125.0
#
#                                    facilities_groups  \
# 0  [Bathroom, Bedroom, Media & Technology, Parkin...
# 1  [Bathroom, Bedroom, View, Outdoors, Kitchen, R...
# 2  [Bathroom, Bedroom, View, Outdoors, Room Ameni...
# 3  [Bathroom, Kitchen, Living Area, Media & Techn...
# 4  [Media & Technology, Parking, Services, Safety...
#
#                                       all_facilities  \
# 0  [[Toilet paper, Towels, Towels/Sheets (extra f...
# 1  [[Toilet paper, Towels, Additional bathroom, B...
# 2  [[Toilet paper, Towels, Bidet, Guest bathroom,...
# 3  [[Private Bathroom, Toilet, Free toiletries, S...
# 4  [[TV], [Daily housekeeping, Concierge], [Fire ...
#
#                                                 link  \
# 0  https://www.booking.com/hotel/ph/reddoorz-near...
# 1  https://www.booking.com/hotel/ph/skylab213b.ht...
# 2  https://www.booking.com/hotel/ph/the-excelsior...
# 3  https://www.booking.com/hotel/ph/rothman-manil...
# 4  https://www.booking.com/hotel/ph/oyo-772-remed...
#
#                                      room_price_dict
# 0  {'Single Room': 1238.0, 'Executive Suite': 185...
# 1  {'Double Room with Shared Bathroom': 1709.0, '...
# 2  {'One Bedroom Suite ': 4788.0, 'Executive Prem...
# 3  {'Deluxe Twin Room': 2545.0, 'Deluxe Double Ro...
# 4  {'Standard Double Room': 1125.0, 'Deluxe Doubl...

# %%
## load scraped data
data2 = pickle.load(open("../data/merged_hotel_data.pkl", "rb"))
data2 = data2.rename(columns={'url': 'link'})
print(data2.shape)
data2.head()
# Out:
# (76536, 31)
#                                 hotel_name_  stars  \
# 0  RedDoorz near East Avenue Medical Center      2
# 1  RedDoorz near East Avenue Medical Center      2
# 2  RedDoorz near East Avenue Medical Center      2
# 3  RedDoorz near East Avenue Medical Center      2
# 4  RedDoorz near East Avenue Medical Center      2
#
#                                             location review_rating  \
# 0  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 2  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 3  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 4  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
#
#                                          description  \
# 0  RedDoorz near East Avenue Medical Center featu...
# 1  RedDoorz near East Avenue Medical Center featu...
# 2  RedDoorz near East Avenue Medical Center featu...
# 3  RedDoorz near East Avenue Medical Center featu...
# 4  RedDoorz near East Avenue Medical Center featu...
#
#                                      main_facilities total_reviews  \
# 0  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 2  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 3  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 4  [Non Smoking Rooms, Free WiFi Internet Access ...            88
#
#                            sub_ratings  \
# 0  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 2  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 3  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 4  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
#
#                               sub_ratings_categories  \
# 0  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                     sub_ratings_dict  ...    room_type_y  \
# 0  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 1  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...   Triple Room
# 2  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 3  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...   Deluxe Room
# 4  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...   Triple Room
#
#    nights_stayed     month_stayed    occupant_type          from_country  \
# 0    1 night        January 2022           Couple            Philippines
# 1   2 nights       November 2022           Family            Philippines
# 2    1 night           June 2022           Couple            Philippines
# 3   6 nights            May 2022    Solo traveler                  India
# 4    1 night            May 2022           Family   United Arab Emirates
#
#    review_score    date_reviewed       short_review  \
# 0           10     January 2022    Ilike The place
# 1          7.0    November 2022            average
# 2          5.0        June 2022               okay
# 3          6.0         May 2022           Pleasant
# 4          7.0         May 2022               Good
#
#                                      positive_review  \
# 0  I like The place and also the staff they're so...
# 1                                           location
# 2                                       The location
# 3                              Its Near my work area
# 4                                       The location
#
#                                      negative_review
# 0
# 1                         room is quite old already.
# 2  There was cockroach and the shower valve does ...
# 3                        Wifi in the room is poor :(
# 4
#
# [5 rows x 31 columns]

# %%
data2 = data2.applymap(lambda x: x.strip() if isinstance(x, str) else x)
data2.head()
data2.columns
# Out:
# Index(['hotel_name_', 'stars', 'location', 'review_rating', 'description',
#        'main_facilities', 'total_reviews', 'sub_ratings',
#        'sub_ratings_categories', 'sub_ratings_dict', 'hotel_surroundings',
#        'hotel_surroundings_distance', 'surroundings_dict', 'room_type_x',
#        'price_list', 'cheapest_price', 'facilities_groups', 'all_facilities',
#        'link', 'room_price_dict', 'name', 'room_type_y', 'nights_stayed',
#        'month_stayed', 'occupant_type', 'from_country', 'review_score',
#        'date_reviewed', 'short_review', 'positive_review', 'negative_review'],
#       dtype='object')

# %% [markdown]
# # Price per Room Type

# %%
df2 = []
for i in range(len(data['link'])):
    hotel_link2 = data['link'][i]
    hotel_name2 = data['hotel_name_'][i]
    sub_data2= data['room_price_dict'][i]
    temp2  = pd.DataFrame.from_dict(sub_data2, orient = 'index').reset_index()
    temp2['link'] = hotel_link2
    temp2['hotel_name_'] = hotel_name2
    temp2.rename(columns = {0:'price', 'index':'room_type'}, inplace = True)
    df2.append(temp2)

# %%
room_price_data2 = pd.concat(df2)
# room_price_data2.to_csv("room_price_data2.csv")

# %%
room_price_data2[room_price_data2['hotel_name_']=="RedDoorz near East Avenue Medical Center"]
# Out:
#              room_type   price  \
# 0          Single Room  1238.0
# 1      Executive Suite  1855.0
# 2          Family Room  2308.0
# 3          Triple Room  1590.0
# 4  Economy Double Room  1413.0
# 5          Deluxe Room   977.0
#
#                                                 link  \
# 0  https://www.booking.com/hotel/ph/reddoorz-near...
# 1  https://www.booking.com/hotel/ph/reddoorz-near...
# 2  https://www.booking.com/hotel/ph/reddoorz-near...
# 3  https://www.booking.com/hotel/ph/reddoorz-near...
# 4  https://www.booking.com/hotel/ph/reddoorz-near...
# 5  https://www.booking.com/hotel/ph/reddoorz-near...
#
#                                 hotel_name_
# 0  RedDoorz near East Avenue Medical Center
# 1  RedDoorz near East Avenue Medical Center
# 2  RedDoorz near East Avenue Medical Center
# 3  RedDoorz near East Avenue Medical Center
# 4  RedDoorz near East Avenue Medical Center
# 5  RedDoorz near East Avenue Medical Center

# %%
data2[data2['hotel_name_']=="RedDoorz near East Avenue Medical Center"]
# Out:
#                                  hotel_name_  stars  \
# 0   RedDoorz near East Avenue Medical Center      2
# 1   RedDoorz near East Avenue Medical Center      2
# 2   RedDoorz near East Avenue Medical Center      2
# 3   RedDoorz near East Avenue Medical Center      2
# 4   RedDoorz near East Avenue Medical Center      2
# ..                                       ...    ...
# 83  RedDoorz near East Avenue Medical Center      2
# 84  RedDoorz near East Avenue Medical Center      2
# 85  RedDoorz near East Avenue Medical Center      2
# 86  RedDoorz near East Avenue Medical Center      2
# 87  RedDoorz near East Avenue Medical Center      2
#
#                                              location review_rating  \
# 0   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 2   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 3   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 4   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# ..                                                ...           ...
# 83  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 84  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 85  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 86  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 87  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
#
#                                           description  \
# 0   RedDoorz near East Avenue Medical Center featu...
# 1   RedDoorz near East Avenue Medical Center featu...
# 2   RedDoorz near East Avenue Medical Center featu...
# 3   RedDoorz near East Avenue Medical Center featu...
# 4   RedDoorz near East Avenue Medical Center featu...
# ..                                                ...
# 83  RedDoorz near East Avenue Medical Center featu...
# 84  RedDoorz near East Avenue Medical Center featu...
# 85  RedDoorz near East Avenue Medical Center featu...
# 86  RedDoorz near East Avenue Medical Center featu...
# 87  RedDoorz near East Avenue Medical Center featu...
#
#                                       main_facilities total_reviews  \
# 0   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 2   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 3   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 4   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# ..                                                ...           ...
# 83  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 84  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 85  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 86  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 87  [Non Smoking Rooms, Free WiFi Internet Access ...            88
#
#                             sub_ratings  \
# 0   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 2   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 3   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 4   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# ..                                  ...
# 83  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 84  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 85  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 86  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 87  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
#
#                                sub_ratings_categories  \
# 0   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4   [Staff, Facilities, Cleanliness, Comfort, Valu...
# ..                                                ...
# 83  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 84  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 85  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 86  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 87  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                      sub_ratings_dict  ...      room_type_y  \
# 0   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 1   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Triple Room
# 2   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 3   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Deluxe Room
# 4   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Triple Room
# ..                                                ...  ...              ...
# 83  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 84  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 85  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Single Room
# 86  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...  Executive Suite
# 87  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
#
#    nights_stayed   month_stayed  occupant_type          from_country  \
# 0        1 night   January 2022         Couple           Philippines
# 1       2 nights  November 2022         Family           Philippines
# 2        1 night      June 2022         Couple           Philippines
# 3       6 nights       May 2022  Solo traveler                 India
# 4        1 night       May 2022         Family  United Arab Emirates
# ..           ...            ...            ...                   ...
# 83     14 nights       May 2022          Group           Philippines
# 84       1 night   January 2021          Group           Philippines
# 85      7 nights     March 2022  Solo traveler              Malaysia
# 86       1 night   January 2020         Couple               Ukraine
# 87       1 night   January 2020          Group                 Spain
#
#     review_score  date_reviewed     short_review  \
# 0             10   January 2022  Ilike The place
# 1            7.0  November 2022          average
# 2            5.0      June 2022             okay
# 3            6.0       May 2022         Pleasant
# 4            7.0       May 2022             Good
# ..           ...            ...              ...
# 83           1.0       May 2022              Bad
# 84           8.0   January 2021        Very Good
# 85           7.0     March 2022             Good
# 86           6.0   January 2020         Pleasant
# 87           7.0   January 2020             Good
#
#                                       positive_review  \
# 0   I like The place and also the staff they're so...
# 1                                            location
# 2                                        The location
# 3                               Its Near my work area
# 4                                        The location
# ..                                                ...
# 83    There are no comments available for this review
# 84    There are no comments available for this review
# 85    There are no comments available for this review
# 86    There are no comments available for this review
# 87    There are no comments available for this review
#
#                                       negative_review
# 0
# 1                          room is quite old already.
# 2   There was cockroach and the shower valve does ...
# 3                         Wifi in the room is poor :(
# 4
# ..                                                ...
# 83
# 84
# 85
# 86
# 87
#
# [88 rows x 31 columns]

# %% [markdown]
# # Merge reviews with price + room type

# %%
data2.shape
# Out:
# (76536, 31)

# %%
data2.head()
# Out:
#                                 hotel_name_  stars  \
# 0  RedDoorz near East Avenue Medical Center      2
# 1  RedDoorz near East Avenue Medical Center      2
# 2  RedDoorz near East Avenue Medical Center      2
# 3  RedDoorz near East Avenue Medical Center      2
# 4  RedDoorz near East Avenue Medical Center      2
#
#                                             location review_rating  \
# 0  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 2  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 3  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 4  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
#
#                                          description  \
# 0  RedDoorz near East Avenue Medical Center featu...
# 1  RedDoorz near East Avenue Medical Center featu...
# 2  RedDoorz near East Avenue Medical Center featu...
# 3  RedDoorz near East Avenue Medical Center featu...
# 4  RedDoorz near East Avenue Medical Center featu...
#
#                                      main_facilities total_reviews  \
# 0  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 2  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 3  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 4  [Non Smoking Rooms, Free WiFi Internet Access ...            88
#
#                            sub_ratings  \
# 0  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 2  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 3  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 4  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
#
#                               sub_ratings_categories  \
# 0  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                     sub_ratings_dict  ...  room_type_y  \
# 0  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 1  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...  Triple Room
# 2  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 3  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...  Deluxe Room
# 4  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...  Triple Room
#
#   nights_stayed   month_stayed  occupant_type          from_country  \
# 0       1 night   January 2022         Couple           Philippines
# 1      2 nights  November 2022         Family           Philippines
# 2       1 night      June 2022         Couple           Philippines
# 3      6 nights       May 2022  Solo traveler                 India
# 4       1 night       May 2022         Family  United Arab Emirates
#
#    review_score  date_reviewed     short_review  \
# 0            10   January 2022  Ilike The place
# 1           7.0  November 2022          average
# 2           5.0      June 2022             okay
# 3           6.0       May 2022         Pleasant
# 4           7.0       May 2022             Good
#
#                                      positive_review  \
# 0  I like The place and also the staff they're so...
# 1                                           location
# 2                                       The location
# 3                              Its Near my work area
# 4                                       The location
#
#                                      negative_review
# 0
# 1                         room is quite old already.
# 2  There was cockroach and the shower valve does ...
# 3                        Wifi in the room is poor :(
# 4
#
# [5 rows x 31 columns]

# %%
data2[data2['link']=="https://www.booking.com/hotel/ph/reddoorz-near-east-avenue-medical-center.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAEJuAEXyAEM2AEB6AEB-AELiAIBqAIDuALa9-ebBsACAdICJDNiMWUxMTlhLTc3ODEtNGI3NC05MWVlLTQ5MDA0MDQzYzY5NNgCBuACAQ&sid=b3a20c12be6b3d4d9b1b0a71b11d8898&aid=304142&ucfs=1&arphpl=1&checkin=2022-12-01&checkout=2022-12-02&dest_id=-2437894&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=301&sr_order=popularity&nflt=ht_id%3D204&srpvid=7ca3572c9035002e&srepoch=1669119903&all_sr_blocks=591802305_0_2_0_0&highlighted_blocks=591802305_0_2_0_0&matching_block_id=591802305_0_2_0_0&sr_pri_blocks=591802305_0_2_0_0__1655&tpi_r=1&from=searchresults#hotelTmpl"]
# Out:
#                                  hotel_name_  stars  \
# 0   RedDoorz near East Avenue Medical Center      2
# 1   RedDoorz near East Avenue Medical Center      2
# 2   RedDoorz near East Avenue Medical Center      2
# 3   RedDoorz near East Avenue Medical Center      2
# 4   RedDoorz near East Avenue Medical Center      2
# ..                                       ...    ...
# 83  RedDoorz near East Avenue Medical Center      2
# 84  RedDoorz near East Avenue Medical Center      2
# 85  RedDoorz near East Avenue Medical Center      2
# 86  RedDoorz near East Avenue Medical Center      2
# 87  RedDoorz near East Avenue Medical Center      2
#
#                                              location review_rating  \
# 0   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 2   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 3   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 4   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# ..                                                ...           ...
# 83  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 84  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 85  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 86  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 87  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
#
#                                           description  \
# 0   RedDoorz near East Avenue Medical Center featu...
# 1   RedDoorz near East Avenue Medical Center featu...
# 2   RedDoorz near East Avenue Medical Center featu...
# 3   RedDoorz near East Avenue Medical Center featu...
# 4   RedDoorz near East Avenue Medical Center featu...
# ..                                                ...
# 83  RedDoorz near East Avenue Medical Center featu...
# 84  RedDoorz near East Avenue Medical Center featu...
# 85  RedDoorz near East Avenue Medical Center featu...
# 86  RedDoorz near East Avenue Medical Center featu...
# 87  RedDoorz near East Avenue Medical Center featu...
#
#                                       main_facilities total_reviews  \
# 0   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 2   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 3   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 4   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# ..                                                ...           ...
# 83  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 84  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 85  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 86  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 87  [Non Smoking Rooms, Free WiFi Internet Access ...            88
#
#                             sub_ratings  \
# 0   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 2   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 3   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 4   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# ..                                  ...
# 83  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 84  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 85  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 86  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 87  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
#
#                                sub_ratings_categories  \
# 0   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4   [Staff, Facilities, Cleanliness, Comfort, Valu...
# ..                                                ...
# 83  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 84  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 85  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 86  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 87  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                      sub_ratings_dict  ...      room_type_y  \
# 0   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 1   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Triple Room
# 2   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 3   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Deluxe Room
# 4   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Triple Room
# ..                                                ...  ...              ...
# 83  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 84  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
# 85  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      Single Room
# 86  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...  Executive Suite
# 87  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...
#
#    nights_stayed   month_stayed  occupant_type          from_country  \
# 0        1 night   January 2022         Couple           Philippines
# 1       2 nights  November 2022         Family           Philippines
# 2        1 night      June 2022         Couple           Philippines
# 3       6 nights       May 2022  Solo traveler                 India
# 4        1 night       May 2022         Family  United Arab Emirates
# ..           ...            ...            ...                   ...
# 83     14 nights       May 2022          Group           Philippines
# 84       1 night   January 2021          Group           Philippines
# 85      7 nights     March 2022  Solo traveler              Malaysia
# 86       1 night   January 2020         Couple               Ukraine
# 87       1 night   January 2020          Group                 Spain
#
#     review_score  date_reviewed     short_review  \
# 0             10   January 2022  Ilike The place
# 1            7.0  November 2022          average
# 2            5.0      June 2022             okay
# 3            6.0       May 2022         Pleasant
# 4            7.0       May 2022             Good
# ..           ...            ...              ...
# 83           1.0       May 2022              Bad
# 84           8.0   January 2021        Very Good
# 85           7.0     March 2022             Good
# 86           6.0   January 2020         Pleasant
# 87           7.0   January 2020             Good
#
#                                       positive_review  \
# 0   I like The place and also the staff they're so...
# 1                                            location
# 2                                        The location
# 3                               Its Near my work area
# 4                                        The location
# ..                                                ...
# 83    There are no comments available for this review
# 84    There are no comments available for this review
# 85    There are no comments available for this review
# 86    There are no comments available for this review
# 87    There are no comments available for this review
#
#                                       negative_review
# 0
# 1                          room is quite old already.
# 2   There was cockroach and the shower valve does ...
# 3                         Wifi in the room is poor :(
# 4
# ..                                                ...
# 83
# 84
# 85
# 86
# 87
#
# [88 rows x 31 columns]

# %%
data2[data2['link']=="https://www.booking.com/hotel/ph/reddoorz-near-east-avenue-medical-center.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAEJuAEXyAEM2AEB6AEB-AELiAIBqAIDuALa9-ebBsACAdICJDNiMWUxMTlhLTc3ODEtNGI3NC05MWVlLTQ5MDA0MDQzYzY5NNgCBuACAQ&sid=b3a20c12be6b3d4d9b1b0a71b11d8898&aid=304142&ucfs=1&arphpl=1&checkin=2022-12-01&checkout=2022-12-02&dest_id=-2437894&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=301&sr_order=popularity&nflt=ht_id%3D204&srpvid=7ca3572c9035002e&srepoch=1669119903&all_sr_blocks=591802305_0_2_0_0&highlighted_blocks=591802305_0_2_0_0&matching_block_id=591802305_0_2_0_0&sr_pri_blocks=591802305_0_2_0_0__1655&tpi_r=1&from=searchresults#hotelTmpl"]['room_type_y'].unique()
# Out:
# array(['', 'Triple Room', 'Deluxe Room', 'Family Room', 'Executive Suite',
#        'Single Room', 'Economy Double Room'], dtype=object)

# %%
room_price_data3 = room_price_data2[["link","room_type","price"]]
room_price_data3.head()
# Out:
#                                                 link            room_type  \
# 0  https://www.booking.com/hotel/ph/reddoorz-near...          Single Room
# 1  https://www.booking.com/hotel/ph/reddoorz-near...      Executive Suite
# 2  https://www.booking.com/hotel/ph/reddoorz-near...          Family Room
# 3  https://www.booking.com/hotel/ph/reddoorz-near...          Triple Room
# 4  https://www.booking.com/hotel/ph/reddoorz-near...  Economy Double Room
#
#     price
# 0  1238.0
# 1  1855.0
# 2  2308.0
# 3  1590.0
# 4  1413.0

# %%
room_price_data3[room_price_data3['link']=="https://www.booking.com/hotel/ph/reddoorz-near-east-avenue-medical-center.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAEJuAEXyAEM2AEB6AEB-AELiAIBqAIDuALa9-ebBsACAdICJDNiMWUxMTlhLTc3ODEtNGI3NC05MWVlLTQ5MDA0MDQzYzY5NNgCBuACAQ&sid=b3a20c12be6b3d4d9b1b0a71b11d8898&aid=304142&ucfs=1&arphpl=1&checkin=2022-12-01&checkout=2022-12-02&dest_id=-2437894&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=301&sr_order=popularity&nflt=ht_id%3D204&srpvid=7ca3572c9035002e&srepoch=1669119903&all_sr_blocks=591802305_0_2_0_0&highlighted_blocks=591802305_0_2_0_0&matching_block_id=591802305_0_2_0_0&sr_pri_blocks=591802305_0_2_0_0__1655&tpi_r=1&from=searchresults#hotelTmpl"]['room_type'].unique()
# Out:
# array(['Single Room', 'Executive Suite', 'Family Room', 'Triple Room',
#        'Economy Double Room', 'Deluxe Room'], dtype=object)

# %%
room_price_data3[room_price_data3['link']=="https://www.booking.com/hotel/ph/reddoorz-near-east-avenue-medical-center.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAEJuAEXyAEM2AEB6AEB-AELiAIBqAIDuALa9-ebBsACAdICJDNiMWUxMTlhLTc3ODEtNGI3NC05MWVlLTQ5MDA0MDQzYzY5NNgCBuACAQ&sid=b3a20c12be6b3d4d9b1b0a71b11d8898&aid=304142&ucfs=1&arphpl=1&checkin=2022-12-01&checkout=2022-12-02&dest_id=-2437894&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=301&sr_order=popularity&nflt=ht_id%3D204&srpvid=7ca3572c9035002e&srepoch=1669119903&all_sr_blocks=591802305_0_2_0_0&highlighted_blocks=591802305_0_2_0_0&matching_block_id=591802305_0_2_0_0&sr_pri_blocks=591802305_0_2_0_0__1655&tpi_r=1&from=searchresults#hotelTmpl"]
# Out:
#                                                 link            room_type  \
# 0  https://www.booking.com/hotel/ph/reddoorz-near...          Single Room
# 1  https://www.booking.com/hotel/ph/reddoorz-near...      Executive Suite
# 2  https://www.booking.com/hotel/ph/reddoorz-near...          Family Room
# 3  https://www.booking.com/hotel/ph/reddoorz-near...          Triple Room
# 4  https://www.booking.com/hotel/ph/reddoorz-near...  Economy Double Room
# 5  https://www.booking.com/hotel/ph/reddoorz-near...          Deluxe Room
#
#     price
# 0  1238.0
# 1  1855.0
# 2  2308.0
# 3  1590.0
# 4  1413.0
# 5   977.0

# %%
data2 = data2.rename(columns={'room_type_y': 'room_type'})

# %%
merged_df_price = data2.merge(room_price_data3,how="left",left_on=['room_type','link'],right_on=['room_type','link'])
merged_df_price.head()
# Out:
#                                 hotel_name_  stars  \
# 0  RedDoorz near East Avenue Medical Center      2
# 1  RedDoorz near East Avenue Medical Center      2
# 2  RedDoorz near East Avenue Medical Center      2
# 3  RedDoorz near East Avenue Medical Center      2
# 4  RedDoorz near East Avenue Medical Center      2
#
#                                             location review_rating  \
# 0  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 2  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 3  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 4  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
#
#                                          description  \
# 0  RedDoorz near East Avenue Medical Center featu...
# 1  RedDoorz near East Avenue Medical Center featu...
# 2  RedDoorz near East Avenue Medical Center featu...
# 3  RedDoorz near East Avenue Medical Center featu...
# 4  RedDoorz near East Avenue Medical Center featu...
#
#                                      main_facilities total_reviews  \
# 0  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 2  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 3  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 4  [Non Smoking Rooms, Free WiFi Internet Access ...            88
#
#                            sub_ratings  \
# 0  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 2  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 3  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 4  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
#
#                               sub_ratings_categories  \
# 0  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                     sub_ratings_dict  ... nights_stayed  \
# 0  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
# 1  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      2 nights
# 2  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
# 3  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      6 nights
# 4  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
#
#     month_stayed  occupant_type          from_country review_score  \
# 0   January 2022         Couple           Philippines           10
# 1  November 2022         Family           Philippines          7.0
# 2      June 2022         Couple           Philippines          5.0
# 3       May 2022  Solo traveler                 India          6.0
# 4       May 2022         Family  United Arab Emirates          7.0
#
#    date_reviewed     short_review  \
# 0   January 2022  Ilike The place
# 1  November 2022          average
# 2      June 2022             okay
# 3       May 2022         Pleasant
# 4       May 2022             Good
#
#                                      positive_review  \
# 0  I like The place and also the staff they're so...
# 1                                           location
# 2                                       The location
# 3                              Its Near my work area
# 4                                       The location
#
#                                      negative_review   price
# 0                                                        NaN
# 1                         room is quite old already.  1590.0
# 2  There was cockroach and the shower valve does ...     NaN
# 3                        Wifi in the room is poor :(   977.0
# 4                                                     1590.0
#
# [5 rows x 32 columns]

# %%
merged_df_price[merged_df_price['link']=="https://www.booking.com/hotel/ph/reddoorz-near-east-avenue-medical-center.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAEJuAEXyAEM2AEB6AEB-AELiAIBqAIDuALa9-ebBsACAdICJDNiMWUxMTlhLTc3ODEtNGI3NC05MWVlLTQ5MDA0MDQzYzY5NNgCBuACAQ&sid=b3a20c12be6b3d4d9b1b0a71b11d8898&aid=304142&ucfs=1&arphpl=1&checkin=2022-12-01&checkout=2022-12-02&dest_id=-2437894&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=301&sr_order=popularity&nflt=ht_id%3D204&srpvid=7ca3572c9035002e&srepoch=1669119903&all_sr_blocks=591802305_0_2_0_0&highlighted_blocks=591802305_0_2_0_0&matching_block_id=591802305_0_2_0_0&sr_pri_blocks=591802305_0_2_0_0__1655&tpi_r=1&from=searchresults#hotelTmpl"]['room_type'].unique()
# Out:
# array(['', 'Triple Room', 'Deluxe Room', 'Family Room', 'Executive Suite',
#        'Single Room', 'Economy Double Room'], dtype=object)

# %%
merged_df_price[merged_df_price['link']=="https://www.booking.com/hotel/ph/reddoorz-near-east-avenue-medical-center.html?label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAEJuAEXyAEM2AEB6AEB-AELiAIBqAIDuALa9-ebBsACAdICJDNiMWUxMTlhLTc3ODEtNGI3NC05MWVlLTQ5MDA0MDQzYzY5NNgCBuACAQ&sid=b3a20c12be6b3d4d9b1b0a71b11d8898&aid=304142&ucfs=1&arphpl=1&checkin=2022-12-01&checkout=2022-12-02&dest_id=-2437894&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=1&hapos=301&sr_order=popularity&nflt=ht_id%3D204&srpvid=7ca3572c9035002e&srepoch=1669119903&all_sr_blocks=591802305_0_2_0_0&highlighted_blocks=591802305_0_2_0_0&matching_block_id=591802305_0_2_0_0&sr_pri_blocks=591802305_0_2_0_0__1655&tpi_r=1&from=searchresults#hotelTmpl"]
# Out:
#                                  hotel_name_  stars  \
# 0   RedDoorz near East Avenue Medical Center      2
# 1   RedDoorz near East Avenue Medical Center      2
# 2   RedDoorz near East Avenue Medical Center      2
# 3   RedDoorz near East Avenue Medical Center      2
# 4   RedDoorz near East Avenue Medical Center      2
# ..                                       ...    ...
# 83  RedDoorz near East Avenue Medical Center      2
# 84  RedDoorz near East Avenue Medical Center      2
# 85  RedDoorz near East Avenue Medical Center      2
# 86  RedDoorz near East Avenue Medical Center      2
# 87  RedDoorz near East Avenue Medical Center      2
#
#                                              location review_rating  \
# 0   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 2   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 3   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 4   90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# ..                                                ...           ...
# 83  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 84  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 85  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 86  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 87  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
#
#                                           description  \
# 0   RedDoorz near East Avenue Medical Center featu...
# 1   RedDoorz near East Avenue Medical Center featu...
# 2   RedDoorz near East Avenue Medical Center featu...
# 3   RedDoorz near East Avenue Medical Center featu...
# 4   RedDoorz near East Avenue Medical Center featu...
# ..                                                ...
# 83  RedDoorz near East Avenue Medical Center featu...
# 84  RedDoorz near East Avenue Medical Center featu...
# 85  RedDoorz near East Avenue Medical Center featu...
# 86  RedDoorz near East Avenue Medical Center featu...
# 87  RedDoorz near East Avenue Medical Center featu...
#
#                                       main_facilities total_reviews  \
# 0   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 2   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 3   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 4   [Non Smoking Rooms, Free WiFi Internet Access ...            88
# ..                                                ...           ...
# 83  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 84  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 85  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 86  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 87  [Non Smoking Rooms, Free WiFi Internet Access ...            88
#
#                             sub_ratings  \
# 0   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 2   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 3   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 4   [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# ..                                  ...
# 83  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 84  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 85  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 86  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 87  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
#
#                                sub_ratings_categories  \
# 0   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3   [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4   [Staff, Facilities, Cleanliness, Comfort, Valu...
# ..                                                ...
# 83  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 84  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 85  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 86  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 87  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                      sub_ratings_dict  ... nights_stayed  \
# 0   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
# 1   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      2 nights
# 2   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
# 3   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      6 nights
# 4   {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
# ..                                                ...  ...           ...
# 83  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...     14 nights
# 84  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
# 85  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...      7 nights
# 86  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
# 87  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...  ...       1 night
#
#      month_stayed  occupant_type          from_country review_score  \
# 0    January 2022         Couple           Philippines           10
# 1   November 2022         Family           Philippines          7.0
# 2       June 2022         Couple           Philippines          5.0
# 3        May 2022  Solo traveler                 India          6.0
# 4        May 2022         Family  United Arab Emirates          7.0
# ..            ...            ...                   ...          ...
# 83       May 2022          Group           Philippines          1.0
# 84   January 2021          Group           Philippines          8.0
# 85     March 2022  Solo traveler              Malaysia          7.0
# 86   January 2020         Couple               Ukraine          6.0
# 87   January 2020          Group                 Spain          7.0
#
#     date_reviewed     short_review  \
# 0    January 2022  Ilike The place
# 1   November 2022          average
# 2       June 2022             okay
# 3        May 2022         Pleasant
# 4        May 2022             Good
# ..            ...              ...
# 83       May 2022              Bad
# 84   January 2021        Very Good
# 85     March 2022             Good
# 86   January 2020         Pleasant
# 87   January 2020             Good
#
#                                       positive_review  \
# 0   I like The place and also the staff they're so...
# 1                                            location
# 2                                        The location
# 3                               Its Near my work area
# 4                                        The location
# ..                                                ...
# 83    There are no comments available for this review
# 84    There are no comments available for this review
# 85    There are no comments available for this review
# 86    There are no comments available for this review
# 87    There are no comments available for this review
#
#                                       negative_review   price
# 0                                                         NaN
# 1                          room is quite old already.  1590.0
# 2   There was cockroach and the shower valve does ...     NaN
# 3                         Wifi in the room is poor :(   977.0
# 4                                                      1590.0
# ..                                                ...     ...
# 83                                                        NaN
# 84                                                        NaN
# 85                                                     1238.0
# 86                                                     1855.0
# 87                                                        NaN
#
# [88 rows x 32 columns]

# %% [markdown]
# # Number of rows without price

# %%
merged_df_price[(merged_df_price['price'].isnull())].shape
# Out:
# (18685, 32)

# %% [markdown]
# # Number of rows without room_type

# %%
merged_df_price[(merged_df_price['room_type'].str.len() == 0)].shape
# merged_df_price3.shape
# Out:
# (17391, 32)

# %%
pickle.dump(merged_df_price, open('../data/merged_hotel_data_withprice.pkl', "wb"))
