# %%
import pickle
import pandas as pd

# %%
## load scraped reviews data
reviews = pickle.load(open("../data/hotel_reviews_final.pkl", "rb"))
reviews = reviews.rename(columns={'url': 'link'})
print(reviews.shape)
reviews.head()
# Out:
# (76536, 12)
# index    name              room_type  nights_stayed     month_stayed  \
# 0        Gene                          2 nights        January 2020
# 1      Sheila   Executive Twin Room     1 night       November 2022
# 2      Greggy   Executive Twin Room     1 night        October 2022
# 3         Tay   Executive Twin Room    2 nights        October 2022
# 4      Joseph   Executive Twin Room     1 night           July 2022
#
# index    occupant_type from_country review_score    date_reviewed  \
# 0              Couple   Philippines          10     January 2020
# 1              Family   Philippines         7.0    November 2022
# 2       Solo traveler   Philippines         8.0     October 2022
# 3              Family      Cambodia         7.0     October 2022
# 4              Family   Philippines         9.0        July 2022
#
# index                                       short_review  \
# 0                                           Exceptional
# 1       Overall, we love the place, the staff and all...
# 2                                                  Nice
# 3                                                  Good
# 4       Overall, it was a very comfortable experience...
#
# index                                    positive_review  \
# 0      I love the pool coz I was so lucky to swim alo...
# 1      We like that all the staff are very friendly. ...
# 2                                 Simple and comfortable
# 3                                                  Staff
# 4      The room was very clean and everything we need...
#
# index                                    negative_review  \
# 0                                              nothing..
# 1      I'm unhappy that we only got plated breakfast ...
# 2                                           the location
# 3      Lack of service facilties not even coffee in r...
# 4
#
# index                                               link
# 0      https://www.booking.com/hotel/ph/meranti.html?...
# 1      https://www.booking.com/hotel/ph/meranti.html?...
# 2      https://www.booking.com/hotel/ph/meranti.html?...
# 3      https://www.booking.com/hotel/ph/meranti.html?...
# 4      https://www.booking.com/hotel/ph/meranti.html?...

# %%
## check info
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76536 entries, 0 to 78298
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             76536 non-null  object
#  1   room_type        76536 non-null  object
#  2   nights_stayed    76536 non-null  object
#  3   month_stayed     76536 non-null  object
#  4   occupant_type    76536 non-null  object
#  5   from_country     76536 non-null  object
#  6   review_score     76536 non-null  object
#  7   date_reviewed    76536 non-null  object
#  8   short_review     76536 non-null  object
#  9   positive_review  76536 non-null  object
#  10  negative_review  76536 non-null  object
#  11  link             76536 non-null  object
# dtypes: object(12)
# memory usage: 7.6+ MB

# %%
## load hotel info
hotels = pickle.load(open("../data/hotel_info_final2.pkl", "rb"))
hotels = hotels.drop('room_price_dict', axis=1)
print(hotels.shape)
hotels.head()
# Out:
# (307, 19)
#                                 hotel_name_  stars  \
# 0  RedDoorz near East Avenue Medical Center      2
# 1                         Skylab Guesthouse      2
# 2             The Excelsior Hotel Las Piñas      4
# 3                             Rothman Hotel      3
# 4                OYO 772 Remedios Apartment      3
#
#                                             location review_rating  \
# 0  90 Matatag Street, Quezon City, 1100 Manila, P...           6.0
# 1  213B, Aldrin Street, Moonwalk Village 1, Parañ...           8.0
# 2  1345 Alabang–Zapote Road, Las Pinas, 1750 Mani...           7.3
# 3  1633 M. Adriatico St., Malate, 1004 Manila, Ph...           7.8
# 4  909, Remedios St, Manila Malate Manila, 1004 M...           6.8
#
#                                          description  \
# 0  RedDoorz near East Avenue Medical Center featu...
# 1  You're eligible for a Genius discount at Skyla...
# 2  Located in Manila, 12.2 km from Mall of Asia A...
# 3  Rothman Hotel is located in the district of Ma...
# 4  You're eligible for a Genius discount at OYO 7...
#
#                                      main_facilities total_reviews  \
# 0  [Non Smoking Rooms, Free WiFi Internet Access ...            88
# 1  [Non Smoking Rooms, Spa & Wellness Centre, Fre...            79
# 2  [Swimming pool, Airport Shuttle, Non Smoking R...             6
# 3  [Non Smoking Rooms, Room-service, Free Parking...            45
# 4  [Non Smoking Rooms, Free WiFi Internet Access ...           113
#
#                            sub_ratings  \
# 0  [6.9, 6.3, 6.5, 6.5, 7.0, 7.8, 6.3]
# 1  [8.8, 7.8, 8.3, 8.4, 8.4, 8.1, 7.5]
# 2  [7.9, 8.3, 7.9, 8.8, 7.9, 7.9, 7.9]
# 3  [8.3, 7.6, 8.0, 7.8, 7.8, 8.7, 8.8]
# 4  [7.5, 6.5, 6.9, 6.9, 7.0, 7.7, 8.8]
#
#                               sub_ratings_categories  \
# 0  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 1  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 2  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 3  [Staff, Facilities, Cleanliness, Comfort, Valu...
# 4  [Staff, Facilities, Cleanliness, Comfort, Valu...
#
#                                     sub_ratings_dict  \
# 0  {'Staff': '6.9', 'Facilities': '6.3', 'Cleanli...
# 1  {'Staff': '8.8', 'Facilities': '7.8', 'Cleanli...
# 2  {'Staff': '7.9', 'Facilities': '8.3', 'Cleanli...
# 3  {'Staff': '8.3', 'Facilities': '7.6', 'Cleanli...
# 4  {'Staff': '7.5', 'Facilities': '6.5', 'Cleanli...
#
#                                   hotel_surroundings  \
# 0  [Quezon City Hall Park and Lagoon, Children's ...
# 1  [Barcelona Park, Guadalajara Park, Continental...
# 2  [Philamlife Village Park, Jasmin Circle open-c...
# 3  [Pedro Gil Park, Manila Baywalk, Remedios Circ...
# 4  [Remedios Circle, MMDA Children's Road Safety ...
#
#                          hotel_surroundings_distance  \
# 0  [900 m, 900 m, 1.1 km, 1.3 km, 1.6 km, 1.6 km,...
# 1  [950 m, 1.3 km, 1.5 km, 1.6 km, 1.7 km, 1.7 km...
# 2  [550 m, 1,000 m, 1 km, 1 km, 1.2 km, 1.4 km, 1...
# 3  [250 m, 450 m, 450 m, 500 m, 750 m, 950 m, 1,0...
# 4  [600 m, 850 m, 950 m, 950 m, 950 m, 1,000 m, 1...
#
#                                    surroundings_dict  \
# 0  {'Quezon City Hall Park and Lagoon': '900 m', ...
# 1  {'Barcelona Park': '950 m', 'Guadalajara Park'...
# 2  {'Philamlife Village Park': '550 m', 'Jasmin C...
# 3  {'Pedro Gil Park': '250 m', 'Manila Baywalk': ...
# 4  {'Remedios Circle': '600 m', 'MMDA Children's ...
#
#                                            room_type  \
# 0  [Deluxe Room, Economy Double Room, Economy Dou...
# 1  [Double Room, Queen Room, Double Room with Sha...
# 2  [Deluxe Room, Deluxe Room, Executive Room, Exe...
# 3  [Renovated King Room, Deluxe Double Room, Delu...
# 4  [Deluxe Double Room, Deluxe Double Room, Stand...
#
#                                           price_list  cheapest_price  \
# 0  [977.0, 1413.0, 1944.0, 1954.0, 2150.0, 1590.0...           977.0
# 1                           [1709.0, 1709.0, 1709.0]          1709.0
# 2  [3010.0, 3571.0, 3724.0, 4357.0, 4499.0, 5077....          3010.0
# 3           [2160.0, 2545.0, 3223.0, 2545.0, 3223.0]          2160.0
# 4                   [1125.0, 1463.0, 1125.0, 1463.0]          1125.0
#
#                                    facilities_groups  \
# 0  [Bathroom, Bedroom, Media & Technology, Parkin...
# 1  [Bathroom, Bedroom, View, Outdoors, Kitchen, R...
# 2  [Bathroom, Bedroom, View, Outdoors, Room Ameni...
# 3  [Bathroom, Kitchen, Living Area, Media & Techn...
# 4  [Media & Technology, Parking, Services, Safety...
#
#                                       all_facilities  \
# 0  [[Toilet paper, Towels, Towels/Sheets (extra f...
# 1  [[Toilet paper, Towels, Additional bathroom, B...
# 2  [[Toilet paper, Towels, Bidet, Guest bathroom,...
# 3  [[Private Bathroom, Toilet, Free toiletries, S...
# 4  [[TV], [Daily housekeeping, Concierge], [Fire ...
#
#                                                 link
# 0  https://www.booking.com/hotel/ph/reddoorz-near...
# 1  https://www.booking.com/hotel/ph/skylab213b.ht...
# 2  https://www.booking.com/hotel/ph/the-excelsior...
# 3  https://www.booking.com/hotel/ph/rothman-manil...
# 4  https://www.booking.com/hotel/ph/oyo-772-remed...

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 0 to 306
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   hotel_name_                  307 non-null    object
#  1   stars                        307 non-null    int64
#  2   location                     307 non-null    object
#  3   review_rating                307 non-null    object
#  4   description                  307 non-null    object
#  5   main_facilities              307 non-null    object
#  6   total_reviews                307 non-null    object
#  7   sub_ratings                  307 non-null    object
#  8   sub_ratings_categories       307 non-null    object
#  9   sub_ratings_dict             307 non-null    object
#  10  hotel_surroundings           307 non-null    object
#  11  hotel_surroundings_distance  307 non-null    object
#  12  surroundings_dict            307 non-null    object
#  13  room_type                    307 non-null    object
#  14  price_list                   307 non-null    object
#  15  cheapest_price               307 non-null    float64
#  16  facilities_groups            307 non-null    object
#  17  all_facilities               307 non-null    object
#  18  link                         307 non-null    object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 48.0+ KB

# %%
## merge the two tables
all = hotels.merge(reviews, on = 'link', how = 'outer')
print(all.shape)
all.info()
# Out:
# (76536, 30)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76536 entries, 0 to 76535
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   hotel_name_                  76536 non-null  object
#  1   stars                        76536 non-null  int64
#  2   location                     76536 non-null  object
#  3   review_rating                76536 non-null  object
#  4   description                  76536 non-null  object
#  5   main_facilities              76536 non-null  object
#  6   total_reviews                76536 non-null  object
#  7   sub_ratings                  76536 non-null  object
#  8   sub_ratings_categories       76536 non-null  object
#  9   sub_ratings_dict             76536 non-null  object
#  10  hotel_surroundings           76536 non-null  object
#  11  hotel_surroundings_distance  76536 non-null  object
#  12  surroundings_dict            76536 non-null  object
#  13  room_type_x                  76536 non-null  object
#  14  price_list                   76536 non-null  object
#  15  cheapest_price               76536 non-null  float64
#  16  facilities_groups            76536 non-null  object
#  17  all_facilities               76536 non-null  object
#  18  link                         76536 non-null  object
#  19  name                         76536 non-null  object
#  20  room_type_y                  76536 non-null  object
#  21  nights_stayed                76536 non-null  object
#  22  month_stayed                 76536 non-null  object
#  23  occupant_type                76536 non-null  object
#  24  from_country                 76536 non-null  object
#  25  review_score                 76536 non-null  object
#  26  date_reviewed                76536 non-null  object
#  27  short_review                 76536 non-null  object
#  28  positive_review              76536 non-null  object
#  29  negative_review              76536 non-null  object
# dtypes: float64(1), int64(1), object(28)
# memory usage: 18.1+ MB

# %%
print("Unique hotel names in hotel data: " + str(hotels['hotel_name_'].nunique()))
print("Unique hotel names in combined data: " + str(all['hotel_name_'].nunique()))
print("\n")
print("Unique links in reviews data: " + str(reviews['link'].nunique()))
print("Unique links in hotels data: " + str(hotels['link'].nunique()))
print("Unique links in combined data: " + str(all['link'].nunique()))
print("\n")
print(reviews.shape)
print(hotels.shape)
print(all.shape)
# Out:
# Unique hotel names in hotel data: 307
# Unique hotel names in combined data: 307
#
#
# Unique links in reviews data: 307
# Unique links in hotels data: 307
# Unique links in combined data: 307
#
#
# (76536, 12)
# (307, 19)
# (76536, 30)

# %%
## save to pickle file
pickle.dump(all, open('../data/merged_hotel_data.pkl', "wb"))
